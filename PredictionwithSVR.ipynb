# %% [markdown]
# #### Introduction
# This is a machine learning project to predict unit/property monthly rent price in Kuala Lumpur region, Malaysia. The project uses a dataset from an online ads listing for property mudah.my. This project outlines the process of web-scraping/ data gathering, data cleaning-wrangling, and machine learning modeling.
#
# This project aims to answers question about how much a unit monthly rent would be if given information such as location, number of bedrooms, parking, furnished, etc? This would help potential tenant and also the owner to get the best price of their rental unit, comparable to the market value.
#
# Some previous work about house pricing was listed below, however most of them are targeting a dataset of house pricing or an Airbnb pricing. There are difference such as in Airbnb, the booking rarely took more than 2 weeks, let alone a year. Therefore the pricing may be different. Additionally, in Airbnb, there is text feature coming from the review given by the tenant and the owner.The better the review, the higher the rent prices -- which was not available in this current project dataset.
#
# Previous work by [@madhuri2019], [@xu2022], [@zhao2022] highlight the importance feature selection, and the choice of machine learning model. Based on the previous works, the most consistently performed machine learning model are Random Forest and Gradient boosting, and the MAE and R2 score usually used in evaluating the performance of the model. Although the above work are all not about apartment rent pricing, similar method can be applied to this project.
#
# The following feature is available in the dataset:
#
# ads_id: ads listing ID, unique to each ads
# prop_name: the building name of the property
# completion_year: year of the building/property completed
# monthly_rent: monthly rent price in Malaysian Ringgit (RM)
# location: the location (region) of the property
# property_type: property type, such as flat, apartment, etc
# rooms: number of rooms
# parking: number of parking spot
# bathroom: number of bathroom
# size: total area of the unit in sq.ft
# furnished: furnishin status of the unit, fully-partial-non
# facilities: main facilities within the unit
# additional_facilities: additional facilities

# %%
import polars as pl
import re
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #### Data Understanding
# Reload the original dataset.

# %%
file_path = "./mudah-apartment-kl-selangor.csv"

# %%
df = pl.read_csv(file_path, infer_schema_length=10000)

# %%
df
# Out:
# shape: (19_991, 14)
# ┌────────────┬─────────┬────────────┬────────────┬───┬─────────┬──────────┬────────────┬───────────┐
# │ ads_id     ┆ prop_na ┆ completion ┆ monthly_re ┆ … ┆ furnish ┆ faciliti ┆ additional ┆ region    │
# │ ---        ┆ me      ┆ _year      ┆ nt         ┆   ┆ ed      ┆ es       ┆ _facilitie ┆ ---       │
# │ i64        ┆ ---     ┆ ---        ┆ ---        ┆   ┆ ---     ┆ ---      ┆ s          ┆ str       │
# │            ┆ str     ┆ f64        ┆ str        ┆   ┆ str     ┆ str      ┆ ---        ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆          ┆ str        ┆           │
# ╞════════════╪═════════╪════════════╪════════════╪═══╪═════════╪══════════╪════════════╪═══════════╡
# │ 100323185  ┆ The     ┆ 2022.0     ┆ RM 4 200   ┆ … ┆ Fully   ┆ Minimart ┆ Air-Cond,  ┆ Kuala     │
# │            ┆ Hipster ┆            ┆ per month  ┆   ┆ Furnish ┆ , Gymnas ┆ Cooking    ┆ Lumpur    │
# │            ┆ @ Taman ┆            ┆            ┆   ┆ ed      ┆ ium, Sec ┆ Allowed,   ┆           │
# │            ┆ Desa    ┆            ┆            ┆   ┆         ┆ urity,   ┆ Washi…     ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ P…       ┆            ┆           │
# │ 100203973  ┆ Segar   ┆ null       ┆ RM 2 300   ┆ … ┆ Partial ┆ Playgrou ┆ Air-Cond,  ┆ Kuala     │
# │            ┆ Courts  ┆            ┆ per month  ┆   ┆ ly Furn ┆ nd,      ┆ Cooking    ┆ Lumpur    │
# │            ┆         ┆            ┆            ┆   ┆ ished   ┆ Parking, ┆ Allowed,   ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Barbeque ┆ Near …     ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ ar…      ┆            ┆           │
# │ 100323128  ┆ Pangsap ┆ null       ┆ RM 1 000   ┆ … ┆ Fully   ┆ Minimart ┆ null       ┆ Kuala     │
# │            ┆ uri     ┆            ┆ per month  ┆   ┆ Furnish ┆ ,        ┆            ┆ Lumpur    │
# │            ┆ Teratak ┆            ┆            ┆   ┆ ed      ┆ Jogging  ┆            ┆           │
# │            ┆ Muhibba ┆            ┆            ┆   ┆         ┆ Track,   ┆            ┆           │
# │            ┆ h 2     ┆            ┆            ┆   ┆         ┆ Lift, S… ┆            ┆           │
# │ 100191767  ┆ Sentul  ┆ 2020.0     ┆ RM 1 700   ┆ … ┆ Partial ┆ Parking, ┆ Cooking    ┆ Kuala     │
# │            ┆ Point   ┆            ┆ per month  ┆   ┆ ly Furn ┆ Playgrou ┆ Allowed,   ┆ Lumpur    │
# │            ┆ Suite   ┆            ┆            ┆   ┆ ished   ┆ nd,      ┆ Near       ┆           │
# │            ┆ Apartme ┆            ┆            ┆   ┆         ┆ Swimming ┆ KTM/LRT,   ┆           │
# │            ┆ nt      ┆            ┆            ┆   ┆         ┆ Po…      ┆ W…         ┆           │
# │ …          ┆ …       ┆ …          ┆ …          ┆ … ┆ …       ┆ …        ┆ …          ┆ …         │
# │ 100371347  ┆ BSP 21  ┆ 2018.0     ┆ RM 1 300   ┆ … ┆ Partial ┆ Jogging  ┆ Air-Cond,  ┆ Selangor  │
# │            ┆         ┆            ┆ per month  ┆   ┆ ly Furn ┆ Track,   ┆ Cooking    ┆           │
# │            ┆         ┆            ┆            ┆   ┆ ished   ┆ Barbeque ┆ Allowed    ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ area,    ┆            ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Pl…      ┆            ┆           │
# │ 100493228  ┆ Ameera  ┆ null       ┆ RM 1 350   ┆ … ┆ Partial ┆ Parking, ┆ Air-Cond,  ┆ Selangor  │
# │            ┆ Residen ┆            ┆ per month  ┆   ┆ ly Furn ┆ Security ┆ Cooking    ┆           │
# │            ┆ ce      ┆            ┆            ┆   ┆ ished   ┆ , Lift,  ┆ Allowed,   ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Swimmin… ┆ Washi…     ┆           │
# │ 100235153  ┆ The Arc ┆ null       ┆ RM 1 200   ┆ … ┆ Fully   ┆ Parking, ┆ Cooking    ┆ Selangor  │
# │            ┆ @ Cyber ┆            ┆ per month  ┆   ┆ Furnish ┆ Security ┆ Allowed,   ┆           │
# │            ┆ jaya    ┆            ┆            ┆   ┆ ed      ┆ , Lift,  ┆ Washing    ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Swimmin… ┆ Machine    ┆           │
# │ 100235168  ┆ Tamarin ┆ 2016.0     ┆ RM 1 000   ┆ … ┆ Partial ┆ Parking, ┆ Air-Cond,  ┆ Selangor  │
# │            ┆ d       ┆            ┆ per month  ┆   ┆ ly Furn ┆ Security ┆ Cooking    ┆           │
# │            ┆ Suites  ┆            ┆            ┆   ┆ ished   ┆ , Lift,  ┆ Allowed,   ┆           │
# │            ┆ @ Cyber ┆            ┆            ┆   ┆         ┆ Swimmin… ┆ Washi…     ┆           │
# │            ┆ jaya    ┆            ┆            ┆   ┆         ┆          ┆            ┆           │
# └────────────┴─────────┴────────────┴────────────┴───┴─────────┴──────────┴────────────┴───────────┘

# %% [markdown]
# ##### Data Description

# %%
df.describe()
# Out:
# shape: (7, 15)
# ┌───────────┬───────────┬─────────┬────────────┬───┬───────────┬──────────┬────────────┬───────────┐
# │ describe  ┆ ads_id    ┆ prop_na ┆ completion ┆ … ┆ furnished ┆ faciliti ┆ additional ┆ region    │
# │ ---       ┆ ---       ┆ me      ┆ _year      ┆   ┆ ---       ┆ es       ┆ _facilitie ┆ ---       │
# │ str       ┆ f64       ┆ ---     ┆ ---        ┆   ┆ str       ┆ ---      ┆ s          ┆ str       │
# │           ┆           ┆ str     ┆ f64        ┆   ┆           ┆ str      ┆ ---        ┆           │
# │           ┆           ┆         ┆            ┆   ┆           ┆          ┆ str        ┆           │
# ╞═══════════╪═══════════╪═════════╪════════════╪═══╪═══════════╪══════════╪════════════╪═══════════╡
# │ count     ┆ 19991.0   ┆ 19991   ┆ 19991.0    ┆ … ┆ 19991     ┆ 19991    ┆ 19991      ┆ 19991     │
# │ null_coun ┆ 0.0       ┆ 948     ┆ 9185.0     ┆ … ┆ 5         ┆ 2209     ┆ 5948       ┆ 0         │
# │ t         ┆           ┆         ┆            ┆   ┆           ┆          ┆            ┆           │
# │ mean      ┆ 9.9707e7  ┆ null    ┆ 2014.82232 ┆ … ┆ null      ┆ null     ┆ null       ┆ null      │
# │           ┆           ┆         ┆ 1          ┆   ┆           ┆          ┆            ┆           │
# │ std       ┆ 3.4826e6  ┆ null    ┆ 6.735355   ┆ … ┆ null      ┆ null     ┆ null       ┆ null      │
# │ min       ┆ 1.6525511 ┆ 1 Harmo ┆ 1977.0     ┆ … ┆ Fully     ┆ Barbeque ┆ ,          ┆ Kuala     │
# │           ┆ e7        ┆ nis     ┆            ┆   ┆ Furnished ┆ area     ┆ Air-Cond,  ┆ Lumpur    │
# │           ┆           ┆         ┆            ┆   ┆           ┆          ┆ Cooking    ┆           │
# │           ┆           ┆         ┆            ┆   ┆           ┆          ┆ Allowed,   ┆           │
# │           ┆           ┆         ┆            ┆   ┆           ┆          ┆ Nea…       ┆           │
# │ max       ┆ 1.0085461 ┆ wangsa  ┆ 2025.0     ┆ … ┆ Partially ┆ Tennis   ┆ Washing    ┆ Selangor  │
# │           ┆ 7e8       ┆ maju    ┆            ┆   ┆ Furnished ┆ Court,   ┆ Machine,   ┆           │
# │           ┆           ┆ section ┆            ┆   ┆           ┆ Swimming ┆ Near       ┆           │
# │           ┆           ┆ 2       ┆            ┆   ┆           ┆ Pool,    ┆ KTM/LRT,   ┆           │
# │           ┆           ┆         ┆            ┆   ┆           ┆ Squ…     ┆ I…         ┆           │
# │ median    ┆ 1.0021267 ┆ null    ┆ 2017.0     ┆ … ┆ null      ┆ null     ┆ null       ┆ null      │
# │           ┆ 8e8       ┆         ┆            ┆   ┆           ┆          ┆            ┆           │
# └───────────┴───────────┴─────────┴────────────┴───┴───────────┴──────────┴────────────┴───────────┘

# %% [markdown]
# ##### Only select house in Kuala Lumpur Region

# %% [raw]
# df = df.filter(pl.col("region") == "Kuala Lumpur")

# %% [markdown]
# ##### Drop Duplicate

# %%
df.filter(df.is_duplicated())
# Out:
# shape: (16, 14)
# ┌───────────┬───────────┬────────────┬────────────┬───┬─────────┬──────────┬────────────┬──────────┐
# │ ads_id    ┆ prop_name ┆ completion ┆ monthly_re ┆ … ┆ furnish ┆ faciliti ┆ additional ┆ region   │
# │ ---       ┆ ---       ┆ _year      ┆ nt         ┆   ┆ ed      ┆ es       ┆ _facilitie ┆ ---      │
# │ i64       ┆ str       ┆ ---        ┆ ---        ┆   ┆ ---     ┆ ---      ┆ s          ┆ str      │
# │           ┆           ┆ f64        ┆ str        ┆   ┆ str     ┆ str      ┆ ---        ┆          │
# │           ┆           ┆            ┆            ┆   ┆         ┆          ┆ str        ┆          │
# ╞═══════════╪═══════════╪════════════╪════════════╪═══╪═════════╪══════════╪════════════╪══════════╡
# │ 100828884 ┆ Saville @ ┆ 2019.0     ┆ RM 1 800   ┆ … ┆ Fully   ┆ Gymnasiu ┆ Air-Cond,  ┆ Selangor │
# │           ┆ Cheras    ┆            ┆ per month  ┆   ┆ Furnish ┆ m,       ┆ Cooking    ┆          │
# │           ┆           ┆            ┆            ┆   ┆ ed      ┆ Squash   ┆ Allowed,   ┆          │
# │           ┆           ┆            ┆            ┆   ┆         ┆ Court,   ┆ Near …     ┆          │
# │           ┆           ┆            ┆            ┆   ┆         ┆ Swimmin… ┆            ┆          │
# │ 100828884 ┆ Saville @ ┆ 2019.0     ┆ RM 1 800   ┆ … ┆ Fully   ┆ Gymnasiu ┆ Air-Cond,  ┆ Selangor │
# │           ┆ Cheras    ┆            ┆ per month  ┆   ┆ Furnish ┆ m,       ┆ Cooking    ┆          │
# │           ┆           ┆            ┆            ┆   ┆ ed      ┆ Squash   ┆ Allowed,   ┆          │
# │           ┆           ┆            ┆            ┆   ┆         ┆ Court,   ┆ Near …     ┆          │
# │           ┆           ┆            ┆            ┆   ┆         ┆ Swimmin… ┆            ┆          │
# │ 100822848 ┆ Taming    ┆ null       ┆ RM 1 200   ┆ … ┆ Fully   ┆ Parking, ┆ Cooking    ┆ Selangor │
# │           ┆ Mutiara   ┆            ┆ per month  ┆   ┆ Furnish ┆ Security ┆ Allowed,   ┆          │
# │           ┆           ┆            ┆            ┆   ┆ ed      ┆ , Lift,  ┆ Washing    ┆          │
# │           ┆           ┆            ┆            ┆   ┆         ┆ Playgro… ┆ Machine    ┆          │
# │ 100822848 ┆ Taming    ┆ null       ┆ RM 1 200   ┆ … ┆ Fully   ┆ Parking, ┆ Cooking    ┆ Selangor │
# │           ┆ Mutiara   ┆            ┆ per month  ┆   ┆ Furnish ┆ Security ┆ Allowed,   ┆          │
# │           ┆           ┆            ┆            ┆   ┆ ed      ┆ , Lift,  ┆ Washing    ┆          │
# │           ┆           ┆            ┆            ┆   ┆         ┆ Playgro… ┆ Machine    ┆          │
# │ …         ┆ …         ┆ …          ┆ …          ┆ … ┆ …       ┆ …        ┆ …          ┆ …        │
# │ 100304102 ┆ Impiria   ┆ 2018.0     ┆ RM 3 300   ┆ … ┆ Fully   ┆ Minimart ┆ null       ┆ Selangor │
# │           ┆ Residensi ┆            ┆ per month  ┆   ┆ Furnish ┆ , Gymnas ┆            ┆          │
# │           ┆ Bukit     ┆            ┆            ┆   ┆ ed      ┆ ium, Sec ┆            ┆          │
# │           ┆ Tinggi K… ┆            ┆            ┆   ┆         ┆ urity,   ┆            ┆          │
# │           ┆           ┆            ┆            ┆   ┆         ┆ P…       ┆            ┆          │
# │ 100304102 ┆ Impiria   ┆ 2018.0     ┆ RM 3 300   ┆ … ┆ Fully   ┆ Minimart ┆ null       ┆ Selangor │
# │           ┆ Residensi ┆            ┆ per month  ┆   ┆ Furnish ┆ , Gymnas ┆            ┆          │
# │           ┆ Bukit     ┆            ┆            ┆   ┆ ed      ┆ ium, Sec ┆            ┆          │
# │           ┆ Tinggi K… ┆            ┆            ┆   ┆         ┆ urity,   ┆            ┆          │
# │           ┆           ┆            ┆            ┆   ┆         ┆ P…       ┆            ┆          │
# │ 100108343 ┆ The Glenz ┆ null       ┆ RM 1 800   ┆ … ┆ Partial ┆ null     ┆ null       ┆ Selangor │
# │           ┆ @         ┆            ┆ per month  ┆   ┆ ly Furn ┆          ┆            ┆          │
# │           ┆ Glenmarie ┆            ┆            ┆   ┆ ished   ┆          ┆            ┆          │
# │ 100108343 ┆ The Glenz ┆ null       ┆ RM 1 800   ┆ … ┆ Partial ┆ null     ┆ null       ┆ Selangor │
# │           ┆ @         ┆            ┆ per month  ┆   ┆ ly Furn ┆          ┆            ┆          │
# │           ┆ Glenmarie ┆            ┆            ┆   ┆ ished   ┆          ┆            ┆          │
# └───────────┴───────────┴────────────┴────────────┴───┴─────────┴──────────┴────────────┴──────────┘

# %%
df = df.unique()

# %% [markdown]
# ##### Extracting Number and Keyword

# %%
df = df.with_columns(pl.col("monthly_rent").apply(lambda x: int(re.search(r'RM (.*?) per', x).group(1).replace(' ', ''))))
df = df.rename({"monthly_rent": "monthly_rent_rm"})

# %%
df = df.with_columns(pl.col("size").apply(lambda x: int(re.search(r'(.*?) sq', x).group(1).replace(' ', ''))))
df = df.rename({'size': 'size_sqft'})

# %%
df = df.with_columns(pl.col("location").apply(lambda x: re.sub(r"Kuala Lumpur - \s*", "", x)))

# %%
df = df.with_columns(pl.col("location").apply(lambda x: re.sub(r"Selangor - \s*", "", x)))

# %%
df
# Out:
# shape: (19_983, 14)
# ┌────────────┬─────────┬────────────┬────────────┬───┬─────────┬──────────┬────────────┬───────────┐
# │ ads_id     ┆ prop_na ┆ completion ┆ monthly_re ┆ … ┆ furnish ┆ faciliti ┆ additional ┆ region    │
# │ ---        ┆ me      ┆ _year      ┆ nt_rm      ┆   ┆ ed      ┆ es       ┆ _facilitie ┆ ---       │
# │ i64        ┆ ---     ┆ ---        ┆ ---        ┆   ┆ ---     ┆ ---      ┆ s          ┆ str       │
# │            ┆ str     ┆ f64        ┆ i64        ┆   ┆ str     ┆ str      ┆ ---        ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆          ┆ str        ┆           │
# ╞════════════╪═════════╪════════════╪════════════╪═══╪═════════╪══════════╪════════════╪═══════════╡
# │ 99857403   ┆ PV 10   ┆ 2008.0     ┆ 1800       ┆ … ┆ Fully   ┆ Gymnasiu ┆ null       ┆ Kuala     │
# │            ┆ Platinu ┆            ┆            ┆   ┆ Furnish ┆ m, Playg ┆            ┆ Lumpur    │
# │            ┆ m Lake  ┆            ┆            ┆   ┆ ed      ┆ round,   ┆            ┆           │
# │            ┆ Condomi ┆            ┆            ┆   ┆         ┆ Tennis   ┆            ┆           │
# │            ┆ nium    ┆            ┆            ┆   ┆         ┆ Co…      ┆            ┆           │
# │ 100771128  ┆ i-Resid ┆ null       ┆ 2200       ┆ … ┆ Partial ┆ Parking, ┆ Air-Cond,  ┆ Selangor  │
# │            ┆ ence @  ┆            ┆            ┆   ┆ ly Furn ┆ Security ┆ Cooking    ┆           │
# │            ┆ i-City  ┆            ┆            ┆   ┆ ished   ┆ , Lift,  ┆ Allowed,   ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Swimmin… ┆ Washi…     ┆           │
# │ 99764975   ┆ Angkasa ┆ 2005.0     ┆ 1700       ┆ … ┆ Fully   ┆ Parking, ┆ Air-Cond,  ┆ Kuala     │
# │            ┆ Condomi ┆            ┆            ┆   ┆ Furnish ┆ Playgrou ┆ Cooking    ┆ Lumpur    │
# │            ┆ niums   ┆            ┆            ┆   ┆ ed      ┆ nd,      ┆ Allowed    ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Swimming ┆            ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Po…      ┆            ┆           │
# │ 100627603  ┆ Tropica ┆ 2020.0     ┆ 1700       ┆ … ┆ Partial ┆ Gymnasiu ┆ null       ┆ Selangor  │
# │            ┆ na Aman ┆            ┆            ┆   ┆ ly Furn ┆ m, Club  ┆            ┆           │
# │            ┆ 1 – Tro ┆            ┆            ┆   ┆ ished   ┆ house,   ┆            ┆           │
# │            ┆ picana  ┆            ┆            ┆   ┆         ┆ Playgrou ┆            ┆           │
# │            ┆ Urb…    ┆            ┆            ┆   ┆         ┆ n…       ┆            ┆           │
# │ …          ┆ …       ┆ …          ┆ …          ┆ … ┆ …       ┆ …        ┆ …          ┆ …         │
# │ 100650520  ┆ Impiria ┆ 2018.0     ┆ 1900       ┆ … ┆ Fully   ┆ Playgrou ┆ null       ┆ Selangor  │
# │            ┆ Residen ┆            ┆            ┆   ┆ Furnish ┆ nd,      ┆            ┆           │
# │            ┆ si      ┆            ┆            ┆   ┆ ed      ┆ Swimming ┆            ┆           │
# │            ┆ Bukit   ┆            ┆            ┆   ┆         ┆ Pool,    ┆            ┆           │
# │            ┆ Tinggi  ┆            ┆            ┆   ┆         ┆ Gymna…   ┆            ┆           │
# │            ┆ K…      ┆            ┆            ┆   ┆         ┆          ┆            ┆           │
# │ 99697896   ┆ Menara  ┆ null       ┆ 1300       ┆ … ┆ Not Fur ┆ Minimart ┆ Cooking    ┆ Kuala     │
# │            ┆ Alpha   ┆            ┆            ┆   ┆ nished  ┆ , Securi ┆ Allowed,   ┆ Lumpur    │
# │            ┆         ┆            ┆            ┆   ┆         ┆ ty,      ┆ Near       ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Swimming ┆ KTM/LRT    ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Poo…     ┆            ┆           │
# │ 100568234  ┆ Hijauan ┆ 2016.0     ┆ 1200       ┆ … ┆ Partial ┆ Swimming ┆ Air-Cond,  ┆ Selangor  │
# │            ┆ Heights ┆            ┆            ┆   ┆ ly Furn ┆ Pool,    ┆ Cooking    ┆           │
# │            ┆         ┆            ┆            ┆   ┆ ished   ┆ Security ┆ Allowed,   ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ , Lift,  ┆ Near …     ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ P…       ┆            ┆           │
# │ 100643140  ┆ Impiria ┆ 2018.0     ┆ 1900       ┆ … ┆ Fully   ┆ Playgrou ┆ null       ┆ Selangor  │
# │            ┆ Residen ┆            ┆            ┆   ┆ Furnish ┆ nd, Mini ┆            ┆           │
# │            ┆ si      ┆            ┆            ┆   ┆ ed      ┆ mart,    ┆            ┆           │
# │            ┆ Bukit   ┆            ┆            ┆   ┆         ┆ Squash   ┆            ┆           │
# │            ┆ Tinggi  ┆            ┆            ┆   ┆         ┆ Cou…     ┆            ┆           │
# │            ┆ K…      ┆            ┆            ┆   ┆         ┆          ┆            ┆           │
# └────────────┴─────────┴────────────┴────────────┴───┴─────────┴──────────┴────────────┴───────────┘

# %% [markdown]
# ##### Extracting Near KTM/LRT
# Hypotheses: closer access to KTM/LRT = higher monthly rent

# %%
# Extracting "near KTM/LRT" into its own column.
def extract_near_ktm_lrt(text):
    pattern = re.compile(r'\bNear KTM/LRT\b')
    try:
        match = pattern.search(text)
        if match:
            return True
        return False
    except TypeError:
        return text

# %%
df["additional_facilities"].apply(lambda x: extract_near_ktm_lrt(x))
# Out:
# shape: (19_983,)
# Series: 'additional_facilities' [bool]
# [
# 	null
# 	false
# 	false
# 	null
# 	null
# 	null
# 	false
# 	true
# 	false
# 	null
# 	false
# 	false
# 	…
# 	true
# 	true
# 	null
# 	null
# 	true
# 	null
# 	null
# 	false
# 	false
# 	null
# 	true
# 	true
# 	null
# ]

# %%
df = df.select([
    pl.all(),
    pl.col("additional_facilities").apply(lambda x: extract_near_ktm_lrt(x)).alias("nearby_railways")
])

# %%
near_ktmlrt = df.filter(pl.col("nearby_railways") == True).select(pl.col("monthly_rent_rm")).median().item()
not_near_ktmlrt = df.filter(pl.col("nearby_railways") == False).select(pl.col("monthly_rent_rm")).median().item()

# %%
f"""
Median:
Nearby KTM/LRT: {near_ktmlrt:.0f} RM
Not nearby KTM/LRT: {not_near_ktmlrt:.0f} RM
"""
# Out:
# '\nMedian:\nNearby KTM/LRT: 1500 RM\nNot nearby KTM/LRT: 1400 RM\n'

# %% [markdown]
# ####
# Plotting the difference between nearby KTM/LRT or not:

# %%
#| label: fig-nearbyktm
#| fig-cap: Boxplot between Nearby KTM/LRT or Not

sns.boxplot(data=df.to_pandas(), x='monthly_rent_rm', y='nearby_railways')
plt.xlim(0,4000)
# Out:
# (0.0, 4000.0)

# %%
df
# Out:
# shape: (19_983, 15)
# ┌──────────┬─────────┬────────────┬────────────┬───┬──────────┬────────────┬──────────┬────────────┐
# │ ads_id   ┆ prop_na ┆ completion ┆ monthly_re ┆ … ┆ faciliti ┆ additional ┆ region   ┆ nearby_rai │
# │ ---      ┆ me      ┆ _year      ┆ nt_rm      ┆   ┆ es       ┆ _facilitie ┆ ---      ┆ lways      │
# │ i64      ┆ ---     ┆ ---        ┆ ---        ┆   ┆ ---      ┆ s          ┆ str      ┆ ---        │
# │          ┆ str     ┆ f64        ┆ i64        ┆   ┆ str      ┆ ---        ┆          ┆ bool       │
# │          ┆         ┆            ┆            ┆   ┆          ┆ str        ┆          ┆            │
# ╞══════════╪═════════╪════════════╪════════════╪═══╪══════════╪════════════╪══════════╪════════════╡
# │ 99857403 ┆ PV 10   ┆ 2008.0     ┆ 1800       ┆ … ┆ Gymnasiu ┆ null       ┆ Kuala    ┆ null       │
# │          ┆ Platinu ┆            ┆            ┆   ┆ m, Playg ┆            ┆ Lumpur   ┆            │
# │          ┆ m Lake  ┆            ┆            ┆   ┆ round,   ┆            ┆          ┆            │
# │          ┆ Condomi ┆            ┆            ┆   ┆ Tennis   ┆            ┆          ┆            │
# │          ┆ nium    ┆            ┆            ┆   ┆ Co…      ┆            ┆          ┆            │
# │ 10077112 ┆ i-Resid ┆ null       ┆ 2200       ┆ … ┆ Parking, ┆ Air-Cond,  ┆ Selangor ┆ false      │
# │ 8        ┆ ence @  ┆            ┆            ┆   ┆ Security ┆ Cooking    ┆          ┆            │
# │          ┆ i-City  ┆            ┆            ┆   ┆ , Lift,  ┆ Allowed,   ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Swimmin… ┆ Washi…     ┆          ┆            │
# │ 99764975 ┆ Angkasa ┆ 2005.0     ┆ 1700       ┆ … ┆ Parking, ┆ Air-Cond,  ┆ Kuala    ┆ false      │
# │          ┆ Condomi ┆            ┆            ┆   ┆ Playgrou ┆ Cooking    ┆ Lumpur   ┆            │
# │          ┆ niums   ┆            ┆            ┆   ┆ nd,      ┆ Allowed    ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Swimming ┆            ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Po…      ┆            ┆          ┆            │
# │ 10062760 ┆ Tropica ┆ 2020.0     ┆ 1700       ┆ … ┆ Gymnasiu ┆ null       ┆ Selangor ┆ null       │
# │ 3        ┆ na Aman ┆            ┆            ┆   ┆ m, Club  ┆            ┆          ┆            │
# │          ┆ 1 – Tro ┆            ┆            ┆   ┆ house,   ┆            ┆          ┆            │
# │          ┆ picana  ┆            ┆            ┆   ┆ Playgrou ┆            ┆          ┆            │
# │          ┆ Urb…    ┆            ┆            ┆   ┆ n…       ┆            ┆          ┆            │
# │ …        ┆ …       ┆ …          ┆ …          ┆ … ┆ …        ┆ …          ┆ …        ┆ …          │
# │ 10065052 ┆ Impiria ┆ 2018.0     ┆ 1900       ┆ … ┆ Playgrou ┆ null       ┆ Selangor ┆ null       │
# │ 0        ┆ Residen ┆            ┆            ┆   ┆ nd,      ┆            ┆          ┆            │
# │          ┆ si      ┆            ┆            ┆   ┆ Swimming ┆            ┆          ┆            │
# │          ┆ Bukit   ┆            ┆            ┆   ┆ Pool,    ┆            ┆          ┆            │
# │          ┆ Tinggi  ┆            ┆            ┆   ┆ Gymna…   ┆            ┆          ┆            │
# │          ┆ K…      ┆            ┆            ┆   ┆          ┆            ┆          ┆            │
# │ 99697896 ┆ Menara  ┆ null       ┆ 1300       ┆ … ┆ Minimart ┆ Cooking    ┆ Kuala    ┆ true       │
# │          ┆ Alpha   ┆            ┆            ┆   ┆ , Securi ┆ Allowed,   ┆ Lumpur   ┆            │
# │          ┆         ┆            ┆            ┆   ┆ ty,      ┆ Near       ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Swimming ┆ KTM/LRT    ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Poo…     ┆            ┆          ┆            │
# │ 10056823 ┆ Hijauan ┆ 2016.0     ┆ 1200       ┆ … ┆ Swimming ┆ Air-Cond,  ┆ Selangor ┆ true       │
# │ 4        ┆ Heights ┆            ┆            ┆   ┆ Pool,    ┆ Cooking    ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Security ┆ Allowed,   ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ , Lift,  ┆ Near …     ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ P…       ┆            ┆          ┆            │
# │ 10064314 ┆ Impiria ┆ 2018.0     ┆ 1900       ┆ … ┆ Playgrou ┆ null       ┆ Selangor ┆ null       │
# │ 0        ┆ Residen ┆            ┆            ┆   ┆ nd, Mini ┆            ┆          ┆            │
# │          ┆ si      ┆            ┆            ┆   ┆ mart,    ┆            ┆          ┆            │
# │          ┆ Bukit   ┆            ┆            ┆   ┆ Squash   ┆            ┆          ┆            │
# │          ┆ Tinggi  ┆            ┆            ┆   ┆ Cou…     ┆            ┆          ┆            │
# │          ┆ K…      ┆            ┆            ┆   ┆          ┆            ┆          ┆            │
# └──────────┴─────────┴────────────┴────────────┴───┴──────────┴────────────┴──────────┴────────────┘

# %%
df.filter(pl.col('prop_name') == 'Majestic Maxim')["nearby_railways"].value_counts()
# Out:
# shape: (3, 2)
# ┌─────────────────┬────────┐
# │ nearby_railways ┆ counts │
# │ ---             ┆ ---    │
# │ bool            ┆ u32    │
# ╞═════════════════╪════════╡
# │ false           ┆ 24     │
# │ true            ┆ 166    │
# │ null            ┆ 32     │
# └─────────────────┴────────┘

# %% [markdown]
# ####
# As seen above, @fig-nearbyktm shows that it sligthly increases the median monthly rent by 50RM. However, near KTM/LRT is not appearing in all row even though the property is the same
#
# Conclusion: Near KTM/LRT may be used, but it can be improved as the listing is inconsistent

# %% [markdown]
# ##### Drop Missing Values in Facilities and Additional Facilities

# %%
df.select(pl.all().is_null()).sum()
# Out:
# shape: (1, 15)
# ┌────────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬────────┬────────────┐
# │ ads_id ┆ prop_name ┆ completion ┆ monthly_re ┆ … ┆ facilities ┆ additional ┆ region ┆ nearby_rai │
# │ ---    ┆ ---       ┆ _year      ┆ nt_rm      ┆   ┆ ---        ┆ _facilitie ┆ ---    ┆ lways      │
# │ u32    ┆ u32       ┆ ---        ┆ ---        ┆   ┆ u32        ┆ s          ┆ u32    ┆ ---        │
# │        ┆           ┆ u32        ┆ u32        ┆   ┆            ┆ ---        ┆        ┆ u32        │
# │        ┆           ┆            ┆            ┆   ┆            ┆ u32        ┆        ┆            │
# ╞════════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════╪════════════╡
# │ 0      ┆ 948       ┆ 9181       ┆ 2          ┆ … ┆ 2208       ┆ 5945       ┆ 0      ┆ 5945       │
# └────────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴────────┴────────────┘

# %%
# #dropping some columns
df = df.drop(['ads_id', 
    'prop_name', 
    'facilities', 
    'additional_facilities'])

# %% [raw]
# df.with_columns(pl.col("rooms").cast(pl.Int64))

# %%
df.select(pl.col("rooms")).unique()
# Out:
# shape: (19, 1)
# ┌──────────────┐
# │ rooms        │
# │ ---          │
# │ str          │
# ╞══════════════╡
# │ 1.0          │
# │ 6.0          │
# │ 3.0          │
# │ 7            │
# │ …            │
# │ 4            │
# │ null         │
# │ More than 10 │
# │ 5            │
# └──────────────┘

# %% [markdown]
# ####
# Converting rooms from object to int64

# %%
df = df.with_columns(pl.col("rooms").apply(lambda x: 10 if x == "More than 10" else x))

# %%
df = df.with_columns(pl.col("rooms").cast(pl.Float64))

# %%
df = df.with_columns(pl.col("rooms").cast(pl.Int64))

# %% [markdown]
# ##### Outlier Removal
# To remove some unexplainable data such as 0 monthly rent, 0 size, the rent that is way too old (1970), including the monthly rent that is way too high and/or size too big.

# %%
#| label: fig-size-rent
#| fig-cap: "Monthly Rent"
df.to_pandas()[['size_sqft', 'monthly_rent_rm']].plot(kind='scatter', x='size_sqft', y='monthly_rent_rm');
plt.ylim(100,5500)
plt.xlim(50,3000)
plt.show()

# %%
#| label: fig-compare-rent
#| fig-cap: "Comparison between Different Scale"
fig, axs = plt.subplots(1,2)
axs[0].boxplot(data=df.to_pandas(), x='monthly_rent_rm')
axs[0].set_ylim(0,20000)
axs[0].set_title('all data')

axs[1].boxplot(data=df.to_pandas(), x='monthly_rent_rm')
axs[1].set_ylim(0,5000)
axs[1].set_title('croped at 5,000 RM')

plt.tight_layout()
plt.show()

# %%
df.to_pandas()["monthly_rent_rm"].plot(kind="box", ylim = (0,20000), title='all data')
# Out:
# <Axes: title={'center': 'all data'}>

# %%
df.to_pandas()["monthly_rent_rm"].plot(kind="box", ylim = (0,5000), title='croped at 5,000 RM')
# Out:
# <Axes: title={'center': 'croped at 5,000 RM'}>

# %% [markdown]
# ####
# Based on EDA on @fig-size-rent and @fig-compare-rent, author decided to filter the data between 100-5500 RM as follows:

# %%
df.columns
# Out:
# ['completion_year',
#  'monthly_rent_rm',
#  'location',
#  'property_type',
#  'rooms',
#  'parking',
#  'bathroom',
#  'size_sqft',
#  'furnished',
#  'region',
#  'nearby_railways']

# %%
# removing all rows with monthly rent above 5500 RM and below 100RM
dfx = df.filter((pl.col("monthly_rent_rm") > 100) & (pl.col("monthly_rent_rm") < 5500))

# %%
dfx.describe()
# Out:
# shape: (7, 12)
# ┌───────────┬────────────┬────────────┬───────────┬───┬─────────┬─────────┬───────────┬────────────┐
# │ describe  ┆ completion ┆ monthly_re ┆ location  ┆ … ┆ size_sq ┆ furnish ┆ region    ┆ nearby_rai │
# │ ---       ┆ _year      ┆ nt_rm      ┆ ---       ┆   ┆ ft      ┆ ed      ┆ ---       ┆ lways      │
# │ str       ┆ ---        ┆ ---        ┆ str       ┆   ┆ ---     ┆ ---     ┆ str       ┆ ---        │
# │           ┆ f64        ┆ f64        ┆           ┆   ┆ f64     ┆ str     ┆           ┆ f64        │
# ╞═══════════╪════════════╪════════════╪═══════════╪═══╪═════════╪═════════╪═══════════╪════════════╡
# │ count     ┆ 19800.0    ┆ 19800.0    ┆ 19800     ┆ … ┆ 19800.0 ┆ 19800   ┆ 19800     ┆ 19800.0    │
# │ null_coun ┆ 9101.0     ┆ 0.0        ┆ 0         ┆ … ┆ 0.0     ┆ 1       ┆ 0         ┆ 5879.0     │
# │ t         ┆            ┆            ┆           ┆   ┆         ┆         ┆           ┆            │
# │ mean      ┆ 2014.85138 ┆ 1564.74454 ┆ null      ┆ … ┆ 5960.48 ┆ null    ┆ null      ┆ 0.534444   │
# │           ┆ 8          ┆ 5          ┆           ┆   ┆ 6768    ┆         ┆           ┆            │
# │ std       ┆ 6.742338   ┆ 710.937121 ┆ null      ┆ … ┆ 710662. ┆ null    ┆ null      ┆ 0.498828   │
# │           ┆            ┆            ┆           ┆   ┆ 728891  ┆         ┆           ┆            │
# │ min       ┆ 1977.0     ┆ 110.0      ┆ 360       ┆ … ┆ 1.0     ┆ Fully   ┆ Kuala     ┆ 0.0        │
# │           ┆            ┆            ┆           ┆   ┆         ┆ Furnish ┆ Lumpur    ┆            │
# │           ┆            ┆            ┆           ┆   ┆         ┆ ed      ┆           ┆            │
# │ max       ┆ 2025.0     ┆ 5499.0     ┆ Wangsa    ┆ … ┆ 9.99999 ┆ Partial ┆ Selangor  ┆ 1.0        │
# │           ┆            ┆            ┆ Maju      ┆   ┆ 99e7    ┆ ly Furn ┆           ┆            │
# │           ┆            ┆            ┆           ┆   ┆         ┆ ished   ┆           ┆            │
# │ median    ┆ 2017.0     ┆ 1400.0     ┆ null      ┆ … ┆ 883.0   ┆ null    ┆ null      ┆ 1.0        │
# └───────────┴────────────┴────────────┴───────────┴───┴─────────┴─────────┴───────────┴────────────┘

# %%
#| label: fig-rent-final
#| fig-cap: "Data after Outlier Removal"
dfx.to_pandas().monthly_rent_rm.plot(kind='box', x='monthly_rent_rm')
# Out:
# <Axes: >

# %%
#| label: fig-size-comparison
#| fig-cap: "Raw Data Size sq.ft"
fig, axs = plt.subplots(1,2)
axs[0].boxplot(data=dfx.to_pandas(), x='size_sqft')
axs[0].set_ylim(0,20000)
axs[0].set_title('all data')

axs[1].boxplot(data=dfx.to_pandas(), x='size_sqft')
axs[1].set_ylim(0,2000)
axs[1].set_title('croped at 0-2,000 square feet')

plt.tight_layout()
plt.show()

# %% [raw]
# dfx.to_pandas()["size_sqft"].plot(kind="box", ylim = (0,20000), title='all data')

# %% [raw]
# dfx.to_pandas()["size_sqft"].plot(kind="box", ylim = (0,2000), title='croped at 2,000 RM')

# %%
#removing outliers below 500, and higher than 3000 sqft and below 50 sqft
dfx = dfx.filter((pl.col("size_sqft") > 50) & (pl.col("size_sqft") < 3000))

# %%
dfx.to_pandas()["size_sqft"].plot(kind='box')
# Out:
# <Axes: >

# %% [raw]
# dfx.drop("monthly_rent_rm").to_pandas()

# %% [raw]
# dfx.select(pl.col("monthly_rent_rm")).to_numpy()

# %%
#| label: fig-complete-outliers
#| fig-cap: "Final Data after Outlier Removal"
fig, axs = plt.subplots(1,5, figsize=(12,4))
axs[0].boxplot(data=dfx.to_pandas().dropna(), x='size_sqft')
axs[1].boxplot(data=dfx.to_pandas().dropna(), x='rooms')
axs[2].boxplot(data=dfx.to_pandas().dropna(), x='parking')
axs[3].boxplot(data=dfx.to_pandas().dropna(), x='bathroom')
# axs[4].boxplot(data=dfx.dropna(), x='completion_year')

axs[0].set_title('Size')
axs[1].set_title('Rooms')
axs[2].set_title('Parking')
axs[3].set_title('Bathrooms')
# axs[4].set_title('Completion Year')

plt.tight_layout()
plt.show()

# %%
dfx.shape
# Out:
# (19761, 11)

# %% [markdown]
# #### Data Preprocessing
# ##### Input-Output

# %% [markdown]
# ##### Train-Test Split Data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(dfx.drop("monthly_rent_rm").to_pandas(),
                                                    dfx.select(pl.col("monthly_rent_rm")).to_numpy(),
                                                    test_size = 0.2,
                                                    random_state = 123)

# %%
len(X_test)/len(dfx.drop("monthly_rent_rm").to_pandas())
# Out:
# 0.20004048378118516

# %%
X_train
# Out:
#        completion_year      location      property_type  rooms  parking
# 3850            2017.0   Wangsa Maju          Apartment    4.0      2.0  \
# 16305              NaN       Puchong          Apartment    3.0      1.0
# 9873               NaN  Sri Petaling        Condominium    3.0      1.0
# 4734            2011.0    Batu Caves        Condominium    3.0      1.0
# 10718              NaN        Cheras        Condominium    3.0      2.0
# ...                ...           ...                ...    ...      ...
# 13435           2017.0   Desa Pandan  Service Residence    3.0      2.0
# 7763            2021.0     Cyberjaya        Condominium    1.0      1.0
# 15377              NaN        Cheras          Apartment    3.0      1.0
# 17730           1987.0   Setiawangsa          Apartment    3.0      1.0
# 15725           2017.0        Cheras  Service Residence    2.0      1.0
#
#        bathroom  size_sqft            furnished        region nearby_railways
# 3850        2.0        850  Partially Furnished  Kuala Lumpur            True
# 16305       2.0        818  Partially Furnished      Selangor            True
# 9873        2.0        946      Fully Furnished  Kuala Lumpur           False
# 4734        2.0       1144      Fully Furnished      Selangor            None
# 10718       2.0        947  Partially Furnished  Kuala Lumpur            True
# ...         ...        ...                  ...           ...             ...
# 13435       2.0        950  Partially Furnished  Kuala Lumpur           False
# 7763        1.0        600      Fully Furnished      Selangor            True
# 15377       1.0        750  Partially Furnished      Selangor           False
# 17730       1.0        820        Not Furnished  Kuala Lumpur            None
# 15725       2.0        680  Partially Furnished  Kuala Lumpur            None
#
# [15808 rows x 10 columns]

# %% [markdown]
# ##### Preprocessing Original Data for Categorical Dtypes
#
# One must paying attention to the number of categorical observation in the original data, with respect to the sampling train-test value. If, the test_size = 0.3, that means any categorical observation with a total of 3 and less, would not be distributed evenly among train and test data.

# %%
print(dfx["location"].n_unique())
print(X_train.location.nunique())
print(X_test.location.nunique())
# Out:
# 127
# 125
# 110

# %%
print(dfx["property_type"].n_unique())
print(X_train.property_type.nunique())
print(X_test.property_type.nunique())
# Out:
# 10
# 10
# 8

# %%
print(set(X_train.furnished.to_list()) - set(X_test.furnished.to_list()))
print(set(X_train.location.to_list()) - set(X_test.location.to_list()))
print(set(X_train.property_type.to_list()) - set(X_test.property_type.to_list()))
print(set(X_train.nearby_railways.to_list()) - set(X_test.nearby_railways.to_list()))
# Out:
# {None}
# {'Damansara Jaya', 'Others', 'Damansara', 'Sungai Penchala', '517', 'Banting', 'Salak Tinggi', 'Bukit Beruntung', 'Bukit Tunku', 'Kuala Selangor', 'Pulau Indah (Pulau Lumut)', 'Telok Panglima Garang', 'Salak Selatan', '369', 'Puncak Jalil', 'Saujana Utama', '43'}
# {'Houses', 'Condo / Services residence / Penthouse / Townhouse'}
# set()

# %% [markdown]
# ####
# Dropping Data

# %%
dfx["location"].value_counts().sort("counts").head(29)
# Out:
# shape: (29, 2)
# ┌───────────────────────────┬────────┐
# │ location                  ┆ counts │
# │ ---                       ┆ ---    │
# │ str                       ┆ u32    │
# ╞═══════════════════════════╪════════╡
# │ Chan Sow Lin              ┆ 1      │
# │ 369                       ┆ 1      │
# │ Pulau Indah (Pulau Lumut) ┆ 1      │
# │ Damansara Jaya            ┆ 1      │
# │ …                         ┆ …      │
# │ Banting                   ┆ 6      │
# │ Beranang                  ┆ 7      │
# │ Jinjang                   ┆ 9      │
# │ Bandar Damai Perdana      ┆ 9      │
# └───────────────────────────┴────────┘

# %%
exclude_location = dfx["location"].value_counts().sort("counts").head(29)["location"].to_numpy()

# %%
exclude_location
# Out:
# array(['369', 'Telok Panglima Garang', '43', 'Puncak Jalil',
#        'Sungai Penchala', 'Chan Sow Lin', 'Damansara Jaya',
#        'Bandar Botanic', 'Pulau Indah (Pulau Lumut)', 'Mutiara Damansara',
#        'Bukit Tunku', 'Damansara', 'Bukit Beruntung', 'KL Eco City',
#        'Bukit Subang', 'Kuala Selangor', 'Hulu Langat', 'Saujana Utama',
#        '517', 'Serendah', 'Salak Tinggi', 'Bandar Bukit Tinggi',
#        'KL Sentral', 'Others', 'Banting', 'Salak Selatan', 'Beranang',
#        'Jinjang', 'Bandar Damai Perdana'], dtype=object)

# %%
dfx["property_type"].value_counts().sort("property_type")
# Out:
# shape: (10, 2)
# ┌───────────────────────────────────┬────────┐
# │ property_type                     ┆ counts │
# │ ---                               ┆ ---    │
# │ str                               ┆ u32    │
# ╞═══════════════════════════════════╪════════╡
# │ Apartment                         ┆ 5232   │
# │ Condo / Services residence / Pen… ┆ 1      │
# │ Condominium                       ┆ 8305   │
# │ Duplex                            ┆ 72     │
# │ …                                 ┆ …      │
# │ Others                            ┆ 87     │
# │ Service Residence                 ┆ 5264   │
# │ Studio                            ┆ 189    │
# │ Townhouse Condo                   ┆ 33     │
# └───────────────────────────────────┴────────┘

# %% [raw]
# dfx_new = dfx.filter(
#     (pl.col("location") != 'Jinjang') & (pl.col("location") != 'Serdang') &
#     (pl.col("location") != 'Sentral') & (pl.col("location") != 'Others') &
#     (pl.col("location") != 'Tunku') & (pl.col("location") != 'Penchala') &
#     (pl.col("location") != 'Lin') &
#     # (pl.col("property_type != 'Others') &
#     (pl.col("property_type") != 'Condo / Services residence / Penthouse / Townhouse') &
#     (pl.col("property_type") != 'Townhouse Condo'))

# %%
dfx_new = dfx.filter((~pl.col("location").is_in(exclude_location.tolist())))
dfx_new = dfx_new.filter((~pl.col("property_type").is_in(["Condo / Services residence / Penthouse / Townhouse", "Townhouse Condo"])))

# %% [raw]
# dfx_new = dfx.filter(
#     (pl.col("location") != 'Chan Sow Lin') & (pl.col("location") != 'Sungai Penchala') &
#     (pl.col("location") != 'Damansara') & (pl.col("location") != 'KL Eco City') &
#     (pl.col("location") != 'Bukit Tunku') & (pl.col("location") != 'Others') &
#     (pl.col("location") != 'KL Sentral') & (pl.col("location") != 'Salak Selatan') &
#     (pl.col("location") != 'Serdang') &  (pl.col("location") != 'Bandar Damai Perdana') &
#     (pl.col("location") != 'Jinjang') &
#     # (pl.col("property_type != 'Others') &
#     (pl.col("property_type") != 'Condo / Services residence / Penthouse / Townhouse') &
#     (pl.col("property_type") != 'Townhouse Condo'))

# %%
dfx_new["property_type"].value_counts()
# Out:
# shape: (7, 2)
# ┌───────────────────┬────────┐
# │ property_type     ┆ counts │
# │ ---               ┆ ---    │
# │ str               ┆ u32    │
# ╞═══════════════════╪════════╡
# │ Service Residence ┆ 5246   │
# │ Duplex            ┆ 72     │
# │ Flat              ┆ 567    │
# │ Studio            ┆ 187    │
# │ Others            ┆ 86     │
# │ Condominium       ┆ 8282   │
# │ Apartment         ┆ 5196   │
# └───────────────────┴────────┘

# %%
dfx_new
# Out:
# shape: (19_636, 11)
# ┌────────────┬────────────┬───────────┬────────────┬───┬─────────┬─────────┬──────────┬────────────┐
# │ completion ┆ monthly_re ┆ location  ┆ property_t ┆ … ┆ size_sq ┆ furnish ┆ region   ┆ nearby_rai │
# │ _year      ┆ nt_rm      ┆ ---       ┆ ype        ┆   ┆ ft      ┆ ed      ┆ ---      ┆ lways      │
# │ ---        ┆ ---        ┆ str       ┆ ---        ┆   ┆ ---     ┆ ---     ┆ str      ┆ ---        │
# │ f64        ┆ i64        ┆           ┆ str        ┆   ┆ i64     ┆ str     ┆          ┆ bool       │
# ╞════════════╪════════════╪═══════════╪════════════╪═══╪═════════╪═════════╪══════════╪════════════╡
# │ 2008.0     ┆ 1800       ┆ Setapak   ┆ Condominiu ┆ … ┆ 1200    ┆ Fully   ┆ Kuala    ┆ null       │
# │            ┆            ┆           ┆ m          ┆   ┆         ┆ Furnish ┆ Lumpur   ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ed      ┆          ┆            │
# │ null       ┆ 2200       ┆ Shah Alam ┆ Service    ┆ … ┆ 1300    ┆ Partial ┆ Selangor ┆ false      │
# │            ┆            ┆           ┆ Residence  ┆   ┆         ┆ ly Furn ┆          ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ished   ┆          ┆            │
# │ 2005.0     ┆ 1700       ┆ Cheras    ┆ Condominiu ┆ … ┆ 920     ┆ Fully   ┆ Kuala    ┆ false      │
# │            ┆            ┆           ┆ m          ┆   ┆         ┆ Furnish ┆ Lumpur   ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ed      ┆          ┆            │
# │ 2020.0     ┆ 1700       ┆ Kuala     ┆ Condominiu ┆ … ┆ 870     ┆ Partial ┆ Selangor ┆ null       │
# │            ┆            ┆ Langat    ┆ m          ┆   ┆         ┆ ly Furn ┆          ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ished   ┆          ┆            │
# │ …          ┆ …          ┆ …         ┆ …          ┆ … ┆ …       ┆ …       ┆ …        ┆ …          │
# │ 2018.0     ┆ 1900       ┆ Klang     ┆ Service    ┆ … ┆ 855     ┆ Fully   ┆ Selangor ┆ null       │
# │            ┆            ┆           ┆ Residence  ┆   ┆         ┆ Furnish ┆          ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ed      ┆          ┆            │
# │ null       ┆ 1300       ┆ Wangsa    ┆ Condominiu ┆ … ┆ 1163    ┆ Not Fur ┆ Kuala    ┆ true       │
# │            ┆            ┆ Maju      ┆ m          ┆   ┆         ┆ nished  ┆ Lumpur   ┆            │
# │ 2016.0     ┆ 1200       ┆ Kajang    ┆ Apartment  ┆ … ┆ 1127    ┆ Partial ┆ Selangor ┆ true       │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ly Furn ┆          ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ished   ┆          ┆            │
# │ 2018.0     ┆ 1900       ┆ Klang     ┆ Service    ┆ … ┆ 855     ┆ Fully   ┆ Selangor ┆ null       │
# │            ┆            ┆           ┆ Residence  ┆   ┆         ┆ Furnish ┆          ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ed      ┆          ┆            │
# └────────────┴────────────┴───────────┴────────────┴───┴─────────┴─────────┴──────────┴────────────┘

# %%
X_train, X_test, y_train, y_test = train_test_split(dfx_new.drop("monthly_rent_rm").to_pandas(),
                                                    dfx_new.select(pl.col("monthly_rent_rm")).to_numpy(),
                                                    test_size = 0.2,
                                                    random_state = 123)

# %%
print(set(X_train.furnished.to_list()) - set(X_test.furnished.to_list()))
print(set(X_train.location.to_list()) - set(X_test.location.to_list()))
print(set(X_train.property_type.to_list()) - set(X_test.property_type.to_list()))
# Out:
# {None}
# set()
# set()

# %%
print(dfx_new["location"].n_unique())
print(X_train.location.nunique())
print(X_test.location.nunique())
# Out:
# 98
# 98
# 98

# %% [markdown]
# ##### Training Data Imputation

# %%
X_train.isna().sum()
# Out:
# completion_year    7229
# location              0
# property_type         0
# rooms                 3
# parking            4473
# bathroom              1
# size_sqft             0
# furnished             1
# region                0
# nearby_railways    4653
# dtype: int64

# %%
X_train_num = X_train.select_dtypes(exclude='object')

# %%
X_train_num.isna().sum()
# Out:
# completion_year    7229
# rooms                 3
# parking            4473
# bathroom              1
# size_sqft             0
# dtype: int64

# %% [markdown]
# #####
# We can fill completion year, rooms, parking and bathroom with mode

# %%
from sklearn.impute import SimpleImputer
def numericalImputation(X_train_num, strategy = 'most_frequent'):
    # create imputer
    imputer_num = SimpleImputer(missing_values = np.nan, strategy = strategy)
    
    # fitting
    imputer_num.fit(X_train_num)

    # transform
    imputed_data = imputer_num.transform(X_train_num)
    X_train_num_imputed = pd.DataFrame(imputed_data)

    # making imputated and non-imputated columns are the same
    X_train_num_imputed.columns = X_train_num.columns
    X_train_num_imputed.index = X_train_num.index

    return X_train_num_imputed, imputer_num

# %%
def numericalImputationNone(X_train_num, strategy = 'most_frequent'):
    # create imputer
    imputer_num = SimpleImputer(missing_values = None, strategy = strategy)
    
    # fitting
    imputer_num.fit(X_train_num)

    # transform
    imputed_data = imputer_num.transform(X_train_num)
    X_train_num_imputed = pd.DataFrame(imputed_data)

    # making imputated and non-imputated columns are the same
    X_train_num_imputed.columns = X_train_num.columns
    X_train_num_imputed.index = X_train_num.index

    return X_train_num_imputed, imputer_num

# %%
X_train_num, imputer_num = numericalImputation(X_train_num, strategy='most_frequent')
X_train_num.isna().sum()
# Out:
# completion_year    0
# rooms              0
# parking            0
# bathroom           0
# size_sqft          0
# dtype: int64

# %% [markdown]
# ##### Categorical Data

# %%
X_train_cat = X_train.select_dtypes(include='object')

# %%
X_train_cat
# Out:
#               location      property_type            furnished        region
# 11478       Setia Alam             Studio  Partially Furnished      Selangor  \
# 12682           Ampang  Service Residence      Fully Furnished  Kuala Lumpur
# 3238            Cheras  Service Residence      Fully Furnished      Selangor
# 6272       Wangsa Maju               Flat        Not Furnished  Kuala Lumpur
# 13753           Gombak  Service Residence  Partially Furnished  Kuala Lumpur
# ...                ...                ...                  ...           ...
# 13435       Mont Kiara  Service Residence      Fully Furnished  Kuala Lumpur
# 7763      Sri Petaling          Apartment  Partially Furnished  Kuala Lumpur
# 15377   Kota Damansara        Condominium      Fully Furnished      Selangor
# 17730  Damansara Damai        Condominium        Not Furnished      Selangor
# 15725    Sri Damansara  Service Residence      Fully Furnished  Kuala Lumpur
#
#       nearby_railways
# 11478           False
# 12682            True
# 3238             True
# 6272             True
# 13753            None
# ...               ...
# 13435           False
# 7763             None
# 15377            True
# 17730            True
# 15725            True
#
# [15708 rows x 5 columns]

# %%
X_train_cat.isna().sum()
# Out:
# location              0
# property_type         0
# furnished             1
# region                0
# nearby_railways    4653
# dtype: int64

# %% [markdown]
# ####
# Impute with mode

# %%
X_train_cat, imputer_num = numericalImputationNone(X_train_cat, strategy='most_frequent')
X_train_cat.isna().sum()
# Out:
# location           0
# property_type      0
# furnished          0
# region             0
# nearby_railways    0
# dtype: int64

# %%
imputer_num
# Out:
# SimpleImputer(missing_values=None, strategy='most_frequent')

# %% [markdown]
# ##### Preprocessing Categorical Variable

# %%
X_train_cat_ohe =  pd.get_dummies(X_train_cat)

# %%
X_train_cat_ohe
# Out:
#        location_360  location_389  location_639  location_Alam Impian
# 11478         False         False         False                 False  \
# 12682         False         False         False                 False
# 3238          False         False         False                 False
# 6272          False         False         False                 False
# 13753         False         False         False                 False
# ...             ...           ...           ...                   ...
# 13435         False         False         False                 False
# 7763          False         False         False                 False
# 15377         False         False         False                 False
# 17730         False         False         False                 False
# 15725         False         False         False                 False
#
#        location_Ampang  location_Ampang Hilir  location_Ara Damansara
# 11478            False                  False                   False  \
# 12682             True                  False                   False
# 3238             False                  False                   False
# 6272             False                  False                   False
# 13753            False                  False                   False
# ...                ...                    ...                     ...
# 13435            False                  False                   False
# 7763             False                  False                   False
# 15377            False                  False                   False
# 17730            False                  False                   False
# 15725            False                  False                   False
#
#        location_Balakong  location_Bandar Bukit Raja  location_Bandar Kinrara
# 11478              False                       False                    False  \
# 12682              False                       False                    False
# 3238               False                       False                    False
# 6272               False                       False                    False
# 13753              False                       False                    False
# ...                  ...                         ...                      ...
# 13435              False                       False                    False
# 7763               False                       False                    False
# 15377              False                       False                    False
# 17730              False                       False                    False
# 15725              False                       False                    False
#
#        ...  property_type_Others  property_type_Service Residence
# 11478  ...                 False                            False  \
# 12682  ...                 False                             True
# 3238   ...                 False                             True
# 6272   ...                 False                            False
# 13753  ...                 False                             True
# ...    ...                   ...                              ...
# 13435  ...                 False                             True
# 7763   ...                 False                            False
# 15377  ...                 False                            False
# 17730  ...                 False                            False
# 15725  ...                 False                             True
#
#        property_type_Studio  furnished_Fully Furnished
# 11478                  True                      False  \
# 12682                 False                       True
# 3238                  False                       True
# 6272                  False                      False
# 13753                 False                      False
# ...                     ...                        ...
# 13435                 False                       True
# 7763                  False                      False
# 15377                 False                       True
# 17730                 False                      False
# 15725                 False                       True
#
#        furnished_Not Furnished  furnished_Partially Furnished
# 11478                    False                           True  \
# 12682                    False                          False
# 3238                     False                          False
# 6272                      True                          False
# 13753                    False                           True
# ...                        ...                            ...
# 13435                    False                          False
# 7763                     False                           True
# 15377                    False                          False
# 17730                     True                          False
# 15725                    False                          False
#
#        region_Kuala Lumpur  region_Selangor  nearby_railways_False
# 11478                False             True                   True  \
# 12682                 True            False                  False
# 3238                 False             True                  False
# 6272                  True            False                  False
# 13753                 True            False                  False
# ...                    ...              ...                    ...
# 13435                 True            False                   True
# 7763                  True            False                  False
# 15377                False             True                  False
# 17730                False             True                  False
# 15725                 True            False                  False
#
#        nearby_railways_True
# 11478                 False
# 12682                  True
# 3238                   True
# 6272                   True
# 13753                  True
# ...                     ...
# 13435                 False
# 7763                   True
# 15377                  True
# 17730                  True
# 15725                  True
#
# [15708 rows x 112 columns]

# %%
ohe_columns = X_train_cat_ohe.columns

# %%
X_train_cat_ohe.isna().sum()
# Out:
# location_360                     0
# location_389                     0
# location_639                     0
# location_Alam Impian             0
# location_Ampang                  0
#                                 ..
# furnished_Partially Furnished    0
# region_Kuala Lumpur              0
# region_Selangor                  0
# nearby_railways_False            0
# nearby_railways_True             0
# Length: 112, dtype: int64

# %%
X_train_num.isna().sum()
# Out:
# completion_year    0
# rooms              0
# parking            0
# bathroom           0
# size_sqft          0
# dtype: int64

# %% [markdown]
# ##### Combine Numerical dan Categorical data

# %%
X_train_concat = pd.concat([X_train_num, X_train_cat_ohe], axis = 1)

# %%
X_train_concat
# Out:
#        completion_year  rooms  parking  bathroom  size_sqft  location_360
# 11478           2015.0    1.0      1.0       1.0      486.0         False  \
# 12682           2015.0    2.0      1.0       2.0      850.0         False
# 3238            2019.0    1.0      1.0       1.0      359.0         False
# 6272            2021.0    2.0      1.0       1.0      550.0         False
# 13753           2019.0    3.0      1.0       2.0      940.0         False
# ...                ...    ...      ...       ...        ...           ...
# 13435           2022.0    1.0      1.0       1.0      300.0         False
# 7763            2021.0    3.0      1.0       2.0      800.0         False
# 15377           2005.0    3.0      1.0       2.0      936.0         False
# 17730           2021.0    3.0      2.0       2.0      751.0         False
# 15725           2021.0    1.0      1.0       1.0      607.0         False
#
#        location_389  location_639  location_Alam Impian  location_Ampang  ...
# 11478         False         False                 False            False  ...  \
# 12682         False         False                 False             True  ...
# 3238          False         False                 False            False  ...
# 6272          False         False                 False            False  ...
# 13753         False         False                 False            False  ...
# ...             ...           ...                   ...              ...  ...
# 13435         False         False                 False            False  ...
# 7763          False         False                 False            False  ...
# 15377         False         False                 False            False  ...
# 17730         False         False                 False            False  ...
# 15725         False         False                 False            False  ...
#
#        property_type_Others  property_type_Service Residence
# 11478                 False                            False  \
# 12682                 False                             True
# 3238                  False                             True
# 6272                  False                            False
# 13753                 False                             True
# ...                     ...                              ...
# 13435                 False                             True
# 7763                  False                            False
# 15377                 False                            False
# 17730                 False                            False
# 15725                 False                             True
#
#        property_type_Studio  furnished_Fully Furnished
# 11478                  True                      False  \
# 12682                 False                       True
# 3238                  False                       True
# 6272                  False                      False
# 13753                 False                      False
# ...                     ...                        ...
# 13435                 False                       True
# 7763                  False                      False
# 15377                 False                       True
# 17730                 False                      False
# 15725                 False                       True
#
#        furnished_Not Furnished  furnished_Partially Furnished
# 11478                    False                           True  \
# 12682                    False                          False
# 3238                     False                          False
# 6272                      True                          False
# 13753                    False                           True
# ...                        ...                            ...
# 13435                    False                          False
# 7763                     False                           True
# 15377                    False                          False
# 17730                     True                          False
# 15725                    False                          False
#
#        region_Kuala Lumpur  region_Selangor  nearby_railways_False
# 11478                False             True                   True  \
# 12682                 True            False                  False
# 3238                 False             True                  False
# 6272                  True            False                  False
# 13753                 True            False                  False
# ...                    ...              ...                    ...
# 13435                 True            False                   True
# 7763                  True            False                  False
# 15377                False             True                  False
# 17730                False             True                  False
# 15725                 True            False                  False
#
#        nearby_railways_True
# 11478                 False
# 12682                  True
# 3238                   True
# 6272                   True
# 13753                  True
# ...                     ...
# 13435                 False
# 7763                   True
# 15377                  True
# 17730                  True
# 15725                  True
#
# [15708 rows x 117 columns]

# %%
X_train_concat.isnull().sum()
# Out:
# completion_year                  0
# rooms                            0
# parking                          0
# bathroom                         0
# size_sqft                        0
#                                 ..
# furnished_Partially Furnished    0
# region_Kuala Lumpur              0
# region_Selangor                  0
# nearby_railways_False            0
# nearby_railways_True             0
# Length: 117, dtype: int64

# %% [markdown]
# #### Standardization

# %%
from sklearn.preprocessing import StandardScaler
def standardizerData(data):
    data_columns = data.columns  #preserve columns
    data_index = data.index  #preserve index

    # create and fit standardizer
    standardizer = StandardScaler()
    standardizer.fit(data)

    # transform data
    standardized_data_raw = standardizer.transform(data)
    standardized_data = pd.DataFrame(standardized_data_raw)
    standardized_data.columns = data_columns
    standardized_data.index = data_index

    return standardized_data, standardizer

# %%
X_train_clean, standardizer = standardizerData(data = X_train_concat)

# %%
X_train_clean
# Out:
#        completion_year     rooms   parking  bathroom  size_sqft  location_360
# 11478        -0.463866 -2.108915 -0.584767 -1.716645  -1.523142     -0.047928  \
# 12682        -0.463866 -0.848333 -0.584767  0.241744  -0.198207     -0.047928
# 3238          0.225580 -2.108915 -0.584767 -1.716645  -1.985413     -0.047928
# 6272          0.570302 -0.848333 -0.584767 -1.716645  -1.290186     -0.047928
# 13753         0.225580  0.412249 -0.584767  0.241744   0.129386     -0.047928
# ...                ...       ...       ...       ...        ...           ...
# 13435         0.742664 -2.108915 -0.584767 -1.716645  -2.200169     -0.047928
# 7763          0.570302  0.412249 -0.584767  0.241744  -0.380204     -0.047928
# 15377        -2.187480  0.412249 -0.584767  0.241744   0.114827     -0.047928
# 17730         0.570302  0.412249  1.389339  0.241744  -0.558560     -0.047928
# 15725         0.570302 -2.108915 -0.584767 -1.716645  -1.082710     -0.047928
#
#        location_389  location_639  location_Alam Impian  location_Ampang  ...
# 11478     -0.049244     -0.025239             -0.036588        -0.188502  ...  \
# 12682     -0.049244     -0.025239             -0.036588         5.304984  ...
# 3238      -0.049244     -0.025239             -0.036588        -0.188502  ...
# 6272      -0.049244     -0.025239             -0.036588        -0.188502  ...
# 13753     -0.049244     -0.025239             -0.036588        -0.188502  ...
# ...             ...           ...                   ...              ...  ...
# 13435     -0.049244     -0.025239             -0.036588        -0.188502  ...
# 7763      -0.049244     -0.025239             -0.036588        -0.188502  ...
# 15377     -0.049244     -0.025239             -0.036588        -0.188502  ...
# 17730     -0.049244     -0.025239             -0.036588        -0.188502  ...
# 15725     -0.049244     -0.025239             -0.036588        -0.188502  ...
#
#        property_type_Others  property_type_Service Residence
# 11478             -0.064957                        -0.597351  \
# 12682             -0.064957                         1.674058
# 3238              -0.064957                         1.674058
# 6272              -0.064957                        -0.597351
# 13753             -0.064957                         1.674058
# ...                     ...                              ...
# 13435             -0.064957                         1.674058
# 7763              -0.064957                        -0.597351
# 15377             -0.064957                        -0.597351
# 17730             -0.064957                        -0.597351
# 15725             -0.064957                         1.674058
#
#        property_type_Studio  furnished_Fully Furnished
# 11478             10.324197                  -0.853037  \
# 12682             -0.096860                   1.172282
# 3238              -0.096860                   1.172282
# 6272              -0.096860                  -0.853037
# 13753             -0.096860                  -0.853037
# ...                     ...                        ...
# 13435             -0.096860                   1.172282
# 7763              -0.096860                  -0.853037
# 15377             -0.096860                   1.172282
# 17730             -0.096860                  -0.853037
# 15725             -0.096860                   1.172282
#
#        furnished_Not Furnished  furnished_Partially Furnished
# 11478                -0.461084                       1.215888  \
# 12682                -0.461084                      -0.822444
# 3238                 -0.461084                      -0.822444
# 6272                  2.168802                      -0.822444
# 13753                -0.461084                       1.215888
# ...                        ...                            ...
# 13435                -0.461084                      -0.822444
# 7763                 -0.461084                       1.215888
# 15377                -0.461084                      -0.822444
# 17730                 2.168802                      -0.822444
# 15725                -0.461084                      -0.822444
#
#        region_Kuala Lumpur  region_Selangor  nearby_railways_False
# 11478            -0.999491         0.999491               1.438669  \
# 12682             1.000509        -1.000509              -0.695087
# 3238             -0.999491         0.999491              -0.695087
# 6272              1.000509        -1.000509              -0.695087
# 13753             1.000509        -1.000509              -0.695087
# ...                    ...              ...                    ...
# 13435             1.000509        -1.000509               1.438669
# 7763              1.000509        -1.000509              -0.695087
# 15377            -0.999491         0.999491              -0.695087
# 17730            -0.999491         0.999491              -0.695087
# 15725             1.000509        -1.000509              -0.695087
#
#        nearby_railways_True
# 11478             -1.438669
# 12682              0.695087
# 3238               0.695087
# 6272               0.695087
# 13753              0.695087
# ...                     ...
# 13435             -1.438669
# 7763               0.695087
# 15377              0.695087
# 17730              0.695087
# 15725              0.695087
#
# [15708 rows x 117 columns]

# %% [markdown]
# ##### Training Machine Learning
# Since this is a regression model, R2 score and mean absolute error (MAE) will be used as a performance metrics.
#
# The machine learning model will use baseline from average value of the target columns (monthly rent) and also result from linear regression model. After that, author used some of the recommended model based on previous works, which are random forest and gradient boosting to better improve the performance of the model.
#
# ##### Baseline-Average Value
# The concept here is to use average value of the target as the easiest way to predict the monhtly rent of a unit.

# %%
y_baseline = np.ones(len(y_train)) * y_train.mean()
y_baseline
# Out:
# array([1565.01343265, 1565.01343265, 1565.01343265, ..., 1565.01343265,
#        1565.01343265, 1565.01343265])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Train the linear regression model
lin_reg = LinearRegression().fit(X_train_clean, y_train)

# Predict using the train data
y_pred_train = y_baseline

# Calculate R-squared
r2_baseline = r2_score(y_train, y_pred_train)

# Calculate MAE
mae_baseline = mean_absolute_error(y_train, y_pred_train)

print(f"R2-score: {r2_baseline:.4f} and MAE score: {mae_baseline:.4f}")
# Out:
# R2-score: 0.0000 and MAE score: 516.7782

# %%
plt.scatter(x=y_train, y=y_pred_train);

# %% [markdown]
# ##### Baseline-Linear Regression
# The second method is using linear regression, which simply put is finding the minum total error (distance) between predicted value and the target value, using linear equation.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Train the linear regression model
lin_reg = LinearRegression().fit(X_train_clean, y_train)

# Predict using the train data
# y_pred = y_baseline
y_pred_train = lin_reg.predict(X_train_clean)

# Calculate mean absolute error
mae_linreg = mean_absolute_error(y_train, y_pred_train)

# Calculate R-squared
r2_linreg = r2_score(y_train, y_pred_train)

print(f"R2-score: {r2_linreg:.4f} and MAE score: {mae_linreg:.4f}")
# Out:
# R2-score: 0.6732 and MAE score: 284.4082

# %%
y_train.flatten()
# Out:
# array([1000, 2200, 1200, ..., 1500, 1250, 2499])

# %%
y_pred_train.shape
# Out:
# (15708, 1)

# %%
sns.jointplot(x=y_train.flatten(), y=y_pred_train.flatten());

# %%
from sklearn.svm import SVR
#from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Train the support vector machine model
svr_reg = SVR(kernel="linear")
svr_reg.fit(X_train_clean, y_train.flatten())

# Predict using the train data
y_pred_train = svr_reg.predict(X_train_clean)

# Calculate R-squared
r2_svr = r2_score(y_train, y_pred_train)

# Calculate MAE
mae_svr = mean_absolute_error(y_train, y_pred_train)

print(f"R2-score: {r2_svr:.4f} and MAE score: {mae_svr:.4f}")
# Out:
# R2-score: 0.6516 and MAE score: 275.7563

# %%
sns.jointplot(x=y_train.flatten(), y=y_pred_train.flatten());

# %%
# GridSearch

from sklearn.model_selection import GridSearchCV 

params = {'C': [1, 10, 100, 1000], 
              'gamma': [0.01, 0.001, 0.0001],
              'kernel': ['linear', 'poly', 'rbf']} 

# Create gridsearch
svr_reg_cv = GridSearchCV(estimator = SVR(), param_grid = params, refit = True, verbose = 3)

# %%
# Fit GridSearchCV
svr_reg_cv.fit(X_train_clean, y_train.flatten())
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.645 total time=   7.8s
# [CV 2/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.644 total time=   8.5s
# [CV 3/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.643 total time=   7.7s
# [CV 4/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.647 total time=   7.7s
# [CV 5/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.657 total time=   7.7s
# [CV 1/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.065 total time=   8.4s
# [CV 2/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.055 total time=   8.4s
# [CV 3/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.079 total time=   8.8s
# [CV 4/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.065 total time=   9.0s
# [CV 5/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.050 total time=   8.5s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.139 total time=  10.6s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.140 total time=  11.6s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.151 total time=  14.1s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.144 total time=  11.1s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.133 total time=  11.1s
# [CV 1/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.645 total time=   8.2s
# [CV 2/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.644 total time=   8.1s
# [CV 3/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.643 total time=   8.8s
# [CV 4/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.647 total time=   8.4s
# [CV 5/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.657 total time=   8.6s
# [CV 1/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.054 total time=   8.6s
# [CV 2/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.055 total time=   8.8s
# [CV 3/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.049 total time=   8.5s
# [CV 4/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.048 total time=   9.0s
# [CV 5/5] END ....C=1, gamma=0.001, kernel=poly;, score=-0.063 total time=   8.9s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.030 total time=  10.9s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.030 total time=  10.7s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.037 total time=  10.9s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.038 total time=  11.4s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.022 total time=  11.2s
# [CV 1/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.645 total time=   8.2s
# [CV 2/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.644 total time=   9.0s
# [CV 3/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.643 total time=   8.2s
# [CV 4/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.647 total time=   8.4s
# [CV 5/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.657 total time=   7.9s
# [CV 1/5] END ...C=1, gamma=0.0001, kernel=poly;, score=-0.054 total time=   8.3s
# [CV 2/5] END ...C=1, gamma=0.0001, kernel=poly;, score=-0.056 total time=   8.2s
# [CV 3/5] END ...C=1, gamma=0.0001, kernel=poly;, score=-0.050 total time=   8.7s
# [CV 4/5] END ...C=1, gamma=0.0001, kernel=poly;, score=-0.048 total time=   9.0s
# [CV 5/5] END ...C=1, gamma=0.0001, kernel=poly;, score=-0.064 total time=   9.1s
# [CV 1/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.044 total time=  11.6s
# [CV 2/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.045 total time=  11.6s
# [CV 3/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.039 total time=  11.9s
# [CV 4/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.038 total time=  11.8s
# [CV 5/5] END ....C=1, gamma=0.0001, kernel=rbf;, score=-0.054 total time=  11.5s
# [CV 1/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.648 total time=   9.8s
# [CV 2/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.648 total time=   9.7s
# [CV 3/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.645 total time=  10.0s
# [CV 4/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.651 total time=   9.6s
# [CV 5/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.662 total time=   9.6s
# [CV 1/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.303 total time=   9.3s
# [CV 2/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.289 total time=   9.4s
# [CV 3/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.307 total time=   9.4s
# [CV 4/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.294 total time=   9.4s
# [CV 5/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.290 total time=   9.6s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.468 total time=  11.1s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.469 total time=  11.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.470 total time=  11.3s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.469 total time=  11.5s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.473 total time=  11.0s
# [CV 1/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.648 total time=   9.4s
# [CV 2/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.648 total time=   9.5s
# [CV 3/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.645 total time=   9.7s
# [CV 4/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.651 total time=   9.6s
# [CV 5/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.662 total time=   9.6s
# [CV 1/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.050 total time=   9.3s
# [CV 2/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.051 total time=   9.4s
# [CV 3/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.042 total time=   9.3s
# [CV 4/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.043 total time=   9.5s
# [CV 5/5] END ...C=10, gamma=0.001, kernel=poly;, score=-0.058 total time=   9.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.361 total time=  11.2s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.359 total time=  11.5s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.374 total time=  11.3s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.366 total time=  11.6s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.359 total time=  11.4s
# [CV 1/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.648 total time=   9.9s
# [CV 2/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.648 total time=   9.4s
# [CV 3/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.645 total time=   9.6s
# [CV 4/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.651 total time=   9.5s
# [CV 5/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.662 total time=   9.5s
# [CV 1/5] END ..C=10, gamma=0.0001, kernel=poly;, score=-0.054 total time=   9.0s
# [CV 2/5] END ..C=10, gamma=0.0001, kernel=poly;, score=-0.056 total time=   9.2s
# [CV 3/5] END ..C=10, gamma=0.0001, kernel=poly;, score=-0.050 total time=   8.9s
# [CV 4/5] END ..C=10, gamma=0.0001, kernel=poly;, score=-0.048 total time=   9.0s
# [CV 5/5] END ..C=10, gamma=0.0001, kernel=poly;, score=-0.064 total time=   9.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.041 total time=  11.8s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.041 total time=  11.3s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.049 total time=  11.2s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.050 total time=  11.3s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.033 total time=  11.3s
# [CV 1/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.648 total time=  16.2s
# [CV 2/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.649 total time=  19.8s
# [CV 3/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.645 total time=  16.9s
# [CV 4/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.651 total time=  19.2s
# [CV 5/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.662 total time=  17.7s
# [CV 1/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.586 total time=  10.4s
# [CV 2/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.585 total time=  11.8s
# [CV 3/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.591 total time=  10.8s
# [CV 4/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.587 total time=  11.6s
# [CV 5/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.600 total time=  11.2s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.632 total time=  12.6s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.639 total time=  12.3s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.633 total time=  12.2s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.637 total time=  12.3s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.655 total time=  13.1s
# [CV 1/5] END .C=100, gamma=0.001, kernel=linear;, score=0.648 total time=  16.9s
# [CV 2/5] END .C=100, gamma=0.001, kernel=linear;, score=0.649 total time=  19.3s
# [CV 3/5] END .C=100, gamma=0.001, kernel=linear;, score=0.645 total time=  17.2s
# [CV 4/5] END .C=100, gamma=0.001, kernel=linear;, score=0.651 total time=  19.5s
# [CV 5/5] END .C=100, gamma=0.001, kernel=linear;, score=0.662 total time=  18.1s
# [CV 1/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.026 total time=  11.3s
# [CV 2/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.029 total time=  10.7s
# [CV 3/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.017 total time=  11.1s
# [CV 4/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.019 total time=  11.1s
# [CV 5/5] END ..C=100, gamma=0.001, kernel=poly;, score=-0.033 total time=  11.2s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.612 total time=  13.1s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.614 total time=  13.1s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.613 total time=  13.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.615 total time=  13.1s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.625 total time=  13.1s
# [CV 1/5] END C=100, gamma=0.0001, kernel=linear;, score=0.648 total time=  16.9s
# [CV 2/5] END C=100, gamma=0.0001, kernel=linear;, score=0.649 total time=  21.0s
# [CV 3/5] END C=100, gamma=0.0001, kernel=linear;, score=0.645 total time=  15.0s
# [CV 4/5] END C=100, gamma=0.0001, kernel=linear;, score=0.651 total time=  16.8s
# [CV 5/5] END C=100, gamma=0.0001, kernel=linear;, score=0.662 total time=  16.1s
# [CV 1/5] END .C=100, gamma=0.0001, kernel=poly;, score=-0.054 total time=  11.1s
# [CV 2/5] END .C=100, gamma=0.0001, kernel=poly;, score=-0.056 total time=  10.8s
# [CV 3/5] END .C=100, gamma=0.0001, kernel=poly;, score=-0.049 total time=  10.2s
# [CV 4/5] END .C=100, gamma=0.0001, kernel=poly;, score=-0.048 total time=  10.7s
# [CV 5/5] END .C=100, gamma=0.0001, kernel=poly;, score=-0.064 total time=  10.7s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.399 total time=  12.5s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.397 total time=  12.5s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.415 total time=  12.3s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.404 total time=  12.7s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.397 total time=  12.8s
# [CV 1/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.648 total time= 1.3min
# [CV 2/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.649 total time= 1.2min
# [CV 3/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.645 total time= 1.0min
# [CV 4/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.651 total time= 1.2min
# [CV 5/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.662 total time= 1.4min
# [CV 1/5] END ...C=1000, gamma=0.01, kernel=poly;, score=0.708 total time=  13.8s
# [CV 2/5] END ...C=1000, gamma=0.01, kernel=poly;, score=0.720 total time=  13.8s
# [CV 3/5] END ...C=1000, gamma=0.01, kernel=poly;, score=0.711 total time=  15.6s
# [CV 4/5] END ...C=1000, gamma=0.01, kernel=poly;, score=0.718 total time=  16.1s
# [CV 5/5] END ...C=1000, gamma=0.01, kernel=poly;, score=0.714 total time=  15.6s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.723 total time=  13.9s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.735 total time=  14.2s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.716 total time=  13.9s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.734 total time=  14.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.737 total time=  14.2s
# [CV 1/5] END C=1000, gamma=0.001, kernel=linear;, score=0.648 total time= 1.3min
# [CV 2/5] END C=1000, gamma=0.001, kernel=linear;, score=0.649 total time= 1.3min
# [CV 3/5] END C=1000, gamma=0.001, kernel=linear;, score=0.645 total time= 1.1min
# [CV 4/5] END C=1000, gamma=0.001, kernel=linear;, score=0.651 total time= 1.3min
# [CV 5/5] END C=1000, gamma=0.001, kernel=linear;, score=0.662 total time= 1.4min
# [CV 1/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.065 total time=  11.2s
# [CV 2/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.055 total time=  11.0s
# [CV 3/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.079 total time=  11.2s
# [CV 4/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.065 total time=  10.9s
# [CV 5/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.050 total time=  10.8s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.663 total time=  12.3s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.668 total time=  11.7s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.664 total time=  10.4s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.664 total time=  10.6s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.681 total time=  10.8s
# [CV 1/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.648 total time= 1.2min
# [CV 2/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.649 total time= 1.2min
# [CV 3/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.645 total time=  57.3s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.651 total time= 1.1min
# [CV 5/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.662 total time= 1.2min
# [CV 1/5] END C=1000, gamma=0.0001, kernel=poly;, score=-0.054 total time=   8.6s
# [CV 2/5] END C=1000, gamma=0.0001, kernel=poly;, score=-0.055 total time=   9.3s
# [CV 3/5] END C=1000, gamma=0.0001, kernel=poly;, score=-0.049 total time=   8.8s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=poly;, score=-0.048 total time=   8.8s
# [CV 5/5] END C=1000, gamma=0.0001, kernel=poly;, score=-0.063 total time=   8.5s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.624 total time=  10.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.624 total time=  10.2s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.624 total time=  10.9s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.626 total time=  10.3s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.635 total time=  10.6s
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [1, 10, 100, 1000],
#                          'gamma': [0.01, 0.001, 0.0001],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              verbose=3)

# %%
svr_reg_cv.best_params_
# Out:
# {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
svr_reg_cv.best_estimator_
# Out:
# SVR(C=1000, gamma=0.01)

# %%
svr_reg = SVR(C = svr_reg_cv.best_params_['C'],
              gamma = svr_reg_cv.best_params_['gamma'],
              kernel = svr_reg_cv.best_params_['kernel'])

# %%
# Refit the Support Vector Regression
svr_reg.fit(X_train_clean, y_train.flatten())

# Predict using the train data
y_pred_train = svr_reg.predict(X_train_clean)

# Calculate R-squared
r2_svr_cv = r2_score(y_train, y_pred_train)

# Calculate MAE
mae_svr_cv = mean_absolute_error(y_train, y_pred_train)

print(f"R2-score: {r2_svr_cv:.4f} and MAE score: {mae_svr_cv:.4f}")
# Out:
# R2-score: 0.6545 and MAE score: 275.6301

# %%
sns.jointplot(x=y_train.flatten(), y=y_pred_train.flatten());

# %% [markdown]
# ##### GradientBoosting
# The gradient boosting, is one of the recommendation from previous works, is a model where each sample would be given a different weights (boosts) depending on its performance in predicting the value/ target.

# %%
from sklearn.ensemble import GradientBoostingRegressor
# Build random forest
grad_tree = GradientBoostingRegressor(random_state = 123)

# %%
# Fit random forest
grad_tree.fit(X_train_clean, y_train.flatten())
# Out:
# GradientBoostingRegressor(random_state=123)

# %%
# Predict
y_pred_train = grad_tree.predict(X_train_clean)
# y_pred_test = grad_tree.predict(X_test_clean)

# Calculate mean absolute error
mae_gb = mean_absolute_error(y_train, y_pred_train)

# Calculate R-squared
r2_gb = r2_score(y_train, y_pred_train)

print(f"R2-score: {r2_gb:.4f} and MAE score: {mae_gb:.4f}")
# Out:
# R2-score: 0.7076 and MAE score: 268.7687

# %%
sns.jointplot(x=y_train.flatten(), y=y_pred_train.flatten());

# %%
# GridSearch

#from sklearn.model_selection import GridSearchCV 


params = {'n_estimators': [100, 200, 300, 400, 500],
              'learning_rate': [0.1, 0.05, 0.01]}

# Create gridsearch
grad_tree = GradientBoostingRegressor(random_state = 123)

grad_tree_cv = GridSearchCV(estimator = grad_tree,
                           param_grid = params,
                           cv = 5,
                           scoring = "neg_mean_absolute_error")

# %%
# Fit GridSearchCV
grad_tree_cv.fit(X_train_clean, y_train.flatten())
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(random_state=123),
#              param_grid={'learning_rate': [0.1, 0.05, 0.01],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              scoring='neg_mean_absolute_error')

# %%
grad_tree_cv.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 500}

# %%
# Refit the Adaboost
grad_tree = GradientBoostingRegressor(n_estimators = grad_tree_cv.best_params_["n_estimators"],
                                      random_state = 123)

grad_tree.fit(X_train_clean, y_train.flatten())
# Out:
# GradientBoostingRegressor(n_estimators=500, random_state=123)

# %%
# Predict
y_pred_train = grad_tree.predict(X_train_clean)

# Calculate mean absolute error
mae_gb_cv = mean_absolute_error(y_train, y_pred_train)

# Calculate R-squared
r2_gb_cv = r2_score(y_train, y_pred_train)

print(f"R2-score: {r2_gb_cv:.4f} and MAE score: {mae_gb_cv:.4f}")
# Out:
# R2-score: 0.7932 and MAE score: 225.5099

# %%
sns.jointplot(x=y_train.flatten(), y=y_pred_train.flatten())

# %% [markdown]
# ##### Random Forest
# The last model, which was also recommended by previous works, is a model where not only it has weights based on its performance, but the feature selection in which the sample is measured was done at random. Therefore, reduces not only the variance, but also the bias.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Build random forest
rf_tree = RandomForestRegressor(n_estimators = 100,
                                criterion = "squared_error",
                                max_features = "sqrt",
                                random_state = 123)

# %%
# Fit random forest
rf_tree.fit(X_train_clean, y_train.flatten())
# Out:
# RandomForestRegressor(max_features='sqrt', random_state=123)

# %%
# Predict
y_pred_train = rf_tree.predict(X_train_clean)

# Calculate mean absolute error
mae_rf = mean_absolute_error(y_train, y_pred_train)

# Calculate R-squared
r2_rf = r2_score(y_train, y_pred_train)

print(f"R2-score: {r2_rf:.4f} and MAE score: {mae_rf:.4f}")
# Out:
# R2-score: 0.9613 and MAE score: 88.5122

# %%
sns.jointplot(x=y_train.flatten(), y=y_pred_train.flatten())

# %%
params = {"n_estimators": [100, 200, 300, 500 ],
          "max_features": ["sqrt", "log2"]}

# Create GridSearch
rf_tree = RandomForestRegressor(criterion = "squared_error",
                                random_state = 123)

rf_tree_cv = GridSearchCV(estimator = rf_tree,
                          param_grid = params,
                          cv = 5,
                          scoring = "neg_mean_absolute_error")

# %%
# Fit grid search cv
rf_tree_cv.fit(X_train_clean, y_train.flatten())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=123),
#              param_grid={'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [100, 200, 300, 500]},
#              scoring='neg_mean_absolute_error')

# %%
# Best params
rf_tree_cv.best_params_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 300}

# %%
# Refit the Random Forest
rf_tree = RandomForestRegressor(criterion = "squared_error",
                                max_features = rf_tree_cv.best_params_["max_features"],
                                n_estimators = rf_tree_cv.best_params_["n_estimators"],
                                random_state = 123)

rf_tree.fit(X_train_clean, y_train.flatten())
# Out:
# RandomForestRegressor(max_features='sqrt', n_estimators=300, random_state=123)

# %%
# Predict
y_pred_train = rf_tree.predict(X_train_clean)

# Calculate mean absolute error
mae_rf_cv = mean_absolute_error(y_train, y_pred_train)

# # Calculate R-squared
r2_rf_cv = r2_score(y_train, y_pred_train)

print(f"R2-score: {r2_rf_cv:.4f} and MAE score: {mae_rf_cv:.4f}")
# Out:
# R2-score: 0.9618 and MAE score: 88.0581

# %%
sns.jointplot(x=y_train.flatten(), y=y_pred_train.flatten())

# %%
mae_score = [mae_baseline, mae_linreg, mae_svr, mae_svr_cv, mae_gb, mae_gb_cv, mae_rf, mae_rf_cv]
r2_score = [r2_baseline, r2_linreg, r2_svr, r2_svr_cv, r2_gb, r2_gb_cv, r2_rf, r2_rf_cv]
indexes = ["baseline", "linear regression", "support vector regreession", "support vector regreession with CV", "gradient boosting", "gradient boosting with CV", "random forest",  "random forest with CV"]

summary_df = pd.DataFrame({
    "MAE Train": mae_score,
    "R2-Score": r2_score,
},index = indexes)

summary_df.sort_values(by='R2-Score', ascending=False)
# Out:
#                                      MAE Train  R2-Score
# random forest with CV                88.058135  0.961782
# random forest                        88.512204  0.961302
# gradient boosting with CV           225.509851  0.793248
# gradient boosting                   268.768668  0.707622
# linear regression                   284.408195  0.673179
# support vector regreession with CV  275.630115  0.654547
# support vector regreession          275.756275  0.651643
# baseline                            516.778212  0.000000

# %% [markdown]
# ####
# From the above table, it can be seen that Random Forest model performs the best, and Gradient Boosting at the second place. This is similar to the previous work done by others, on house pricing.

# %% [markdown]
# ##### Best Model

# %%
# Libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score


# Setting up
rf_tree = RandomForestRegressor(n_estimators = 500,
                                criterion = "squared_error",
                                max_features = "sqrt",
                                random_state = 123)

# Fit model train
rf_tree.fit(X_train_clean, y_train.flatten())

# Predict model train
y_pred_train = rf_tree.predict(X_train_clean)

# Calculate mean absolute error
mae_rf_cv_train = mean_absolute_error(y_train, y_pred_train)

# Calculate R-squared
r2_rf_cv_train = r2_score(y_train, y_pred_train)

print(f"R2-score: {r2_rf_cv_train:.3f} and MAE score: +/-{mae_rf_cv_train:.2f} RM")

sns.scatterplot(x=y_train.flatten(), y=y_pred_train.flatten() )
plt.plot([0, 5500], [0,5500], "--r")
plt.xlim(0, 5500)
plt.xlabel("Actual Monthly Rent")
plt.ylim(0,5500)
plt.ylabel("Predicted Monthly Rent")
plt.suptitle("Random Forest - Best Regression Model")
plt.show()
# Out:
# R2-score: 0.962 and MAE score: +/-87.84 RM

# %% [markdown]
# ### Data Prediction

# %% [markdown]
# ##### Test Data Preprocessing
# Simlar process done in train dataset need to be repeated on test dataset.

# %%
# Checking null data
X_test.isna().sum()
# Out:
# completion_year    1762
# location              0
# property_type         0
# rooms                 0
# parking            1123
# bathroom              0
# size_sqft             0
# furnished             0
# region                0
# nearby_railways    1161
# dtype: int64

# %%
X_test_num =  X_test.select_dtypes(exclude='object')
X_test_num
# Out:
#        completion_year  rooms  parking  bathroom  size_sqft
# 6522            2005.0    3.0      1.0       2.0        950
# 2183            2013.0    2.0      1.0       1.0        797
# 12548           1999.0    3.0      1.0       2.0       1066
# 18697           2018.0    3.0      NaN       2.0        891
# 1395            2015.0    4.0      NaN       2.0       1142
# ...                ...    ...      ...       ...        ...
# 2168               NaN    3.0      1.0       2.0        800
# 8514            2020.0    3.0      2.0       2.0       1100
# 10228           2014.0    3.0      2.0       2.0       1328
# 7260               NaN    1.0      1.0       1.0        533
# 17870           2021.0    1.0      NaN       1.0        452
#
# [3928 rows x 5 columns]

# %%
X_test_num.isna().sum()
# Out:
# completion_year    1762
# rooms                 0
# parking            1123
# bathroom              0
# size_sqft             0
# dtype: int64

# %%
X_test_num, imputer_num = numericalImputation(X_test_num, strategy='most_frequent')
X_test_num.isna().sum()
# Out:
# completion_year    0
# rooms              0
# parking            0
# bathroom           0
# size_sqft          0
# dtype: int64

# %% [markdown]
# ##### Categorical Data

# %%
X_test_cat = X_test.select_dtypes(include='object')
X_test_cat
# Out:
#               location      property_type            furnished        region
# 6522    Seri Kembangan        Condominium      Fully Furnished      Selangor  \
# 2183   Mid Valley City  Service Residence      Fully Furnished  Kuala Lumpur
# 12548          Puchong        Condominium  Partially Furnished      Selangor
# 18697           Ampang  Service Residence      Fully Furnished  Kuala Lumpur
# 1395            Cheras        Condominium  Partially Furnished  Kuala Lumpur
# ...                ...                ...                  ...           ...
# 2168          Balakong          Apartment        Not Furnished      Selangor
# 8514       Bukit Jalil        Condominium      Fully Furnished  Kuala Lumpur
# 10228      Kuchai Lama        Condominium      Fully Furnished  Kuala Lumpur
# 7260            Cheras  Service Residence  Partially Furnished      Selangor
# 17870   Seri Kembangan             Studio      Fully Furnished      Selangor
#
#       nearby_railways
# 6522             True
# 2183             True
# 12548           False
# 18697            None
# 1395             None
# ...               ...
# 2168             True
# 8514             None
# 10228            True
# 7260             None
# 17870            True
#
# [3928 rows x 5 columns]

# %%
X_test_cat.isna().sum()
# Out:
# location              0
# property_type         0
# furnished             0
# region                0
# nearby_railways    1161
# dtype: int64

# %%
X_test_cat, imputer_num = numericalImputationNone(X_test_cat, strategy='most_frequent')
X_test_cat.isna().sum()
# Out:
# location           0
# property_type      0
# furnished          0
# region             0
# nearby_railways    0
# dtype: int64

# %% [markdown]
# #### Categorical OHE

# %%
X_test_cat_ohe =  pd.get_dummies(X_test_cat)
X_test_cat_ohe.head(2)
# Out:
#       location_360  location_389  location_639  location_Alam Impian
# 6522         False         False         False                 False  \
# 2183         False         False         False                 False
#
#       location_Ampang  location_Ampang Hilir  location_Ara Damansara
# 6522            False                  False                   False  \
# 2183            False                  False                   False
#
#       location_Balakong  location_Bandar Bukit Raja  location_Bandar Kinrara
# 6522              False                       False                    False  \
# 2183              False                       False                    False
#
#       ...  property_type_Others  property_type_Service Residence
# 6522  ...                 False                            False  \
# 2183  ...                 False                             True
#
#       property_type_Studio  furnished_Fully Furnished
# 6522                 False                       True  \
# 2183                 False                       True
#
#       furnished_Not Furnished  furnished_Partially Furnished
# 6522                    False                          False  \
# 2183                    False                          False
#
#       region_Kuala Lumpur  region_Selangor  nearby_railways_False
# 6522                False             True                  False  \
# 2183                 True            False                  False
#
#       nearby_railways_True
# 6522                  True
# 2183                  True
#
# [2 rows x 112 columns]

# %%
ohe_columns = X_test_cat_ohe.columns
ohe_columns
# Out:
# Index(['location_360', 'location_389', 'location_639', 'location_Alam Impian',
#        'location_Ampang', 'location_Ampang Hilir', 'location_Ara Damansara',
#        'location_Balakong', 'location_Bandar Bukit Raja',
#        'location_Bandar Kinrara',
#        ...
#        'property_type_Others', 'property_type_Service Residence',
#        'property_type_Studio', 'furnished_Fully Furnished',
#        'furnished_Not Furnished', 'furnished_Partially Furnished',
#        'region_Kuala Lumpur', 'region_Selangor', 'nearby_railways_False',
#        'nearby_railways_True'],
#       dtype='object', length=112)

# %%
X_test_concat = pd.concat([X_test_num,
                            X_test_cat_ohe],
                           axis = 1)

# %%
X_test_concat.head(2)
# Out:
#       completion_year  rooms  parking  bathroom  size_sqft  location_360
# 6522           2005.0    3.0      1.0       2.0      950.0         False  \
# 2183           2013.0    2.0      1.0       1.0      797.0         False
#
#       location_389  location_639  location_Alam Impian  location_Ampang  ...
# 6522         False         False                 False            False  ...  \
# 2183         False         False                 False            False  ...
#
#       property_type_Others  property_type_Service Residence
# 6522                 False                            False  \
# 2183                 False                             True
#
#       property_type_Studio  furnished_Fully Furnished
# 6522                 False                       True  \
# 2183                 False                       True
#
#       furnished_Not Furnished  furnished_Partially Furnished
# 6522                    False                          False  \
# 2183                    False                          False
#
#       region_Kuala Lumpur  region_Selangor  nearby_railways_False
# 6522                False             True                  False  \
# 2183                 True            False                  False
#
#       nearby_railways_True
# 6522                  True
# 2183                  True
#
# [2 rows x 117 columns]

# %%
#sanity check
X_test_concat.isnull().sum()
# Out:
# completion_year                  0
# rooms                            0
# parking                          0
# bathroom                         0
# size_sqft                        0
#                                 ..
# furnished_Partially Furnished    0
# region_Kuala Lumpur              0
# region_Selangor                  0
# nearby_railways_False            0
# nearby_railways_True             0
# Length: 117, dtype: int64

# %% [markdown]
# ##### Standardization

# %%
from sklearn.preprocessing import StandardScaler
def standardizerData(data):
    data_columns = data.columns  # agar nama kolom tidak hilang
    data_index = data.index  # agar index tidak hilang

    # create and fit standardizer
    standardizer = StandardScaler()
    standardizer.fit(data)

    # transform data
    standardized_data_raw = standardizer.transform(data)
    standardized_data = pd.DataFrame(standardized_data_raw)
    standardized_data.columns = data_columns
    standardized_data.index = data_index

    return standardized_data, standardizer

# %%
X_test_clean, standardizer = standardizerData(data = X_test_concat)

# %%
X_test_clean.head()
# Out:
#        completion_year     rooms   parking  bathroom  size_sqft  location_360
# 6522         -2.108039  0.422751 -0.565248  0.247482   0.163204     -0.061914  \
# 2183         -0.765837 -0.822051 -0.565248 -1.704543  -0.394609     -0.061914
# 12548        -3.114690  0.422751 -0.565248  0.247482   0.586121     -0.061914
# 18697         0.073039  0.422751 -0.565248  0.247482  -0.051900     -0.061914
# 1395         -0.430287  1.667554 -0.565248  0.247482   0.863205     -0.061914
#
#        location_389  location_639  location_Alam Impian  location_Ampang  ...
# 6522      -0.042252     -0.035701             -0.027647        -0.169738  ...  \
# 2183      -0.042252     -0.035701             -0.027647        -0.169738  ...
# 12548     -0.042252     -0.035701             -0.027647        -0.169738  ...
# 18697     -0.042252     -0.035701             -0.027647         5.891442  ...
# 1395      -0.042252     -0.035701             -0.027647        -0.169738  ...
#
#        property_type_Others  property_type_Service Residence
# 6522              -0.071538                        -0.629582  \
# 2183              -0.071538                         1.588354
# 12548             -0.071538                        -0.629582
# 18697             -0.071538                         1.588354
# 1395              -0.071538                        -0.629582
#
#        property_type_Studio  furnished_Fully Furnished
# 6522              -0.102703                   1.156761  \
# 2183              -0.102703                   1.156761
# 12548             -0.102703                  -0.864483
# 18697             -0.102703                   1.156761
# 1395              -0.102703                  -0.864483
#
#        furnished_Not Furnished  furnished_Partially Furnished
# 6522                 -0.462433                      -0.809930  \
# 2183                 -0.462433                      -0.809930
# 12548                -0.462433                       1.234675
# 18697                -0.462433                      -0.809930
# 1395                 -0.462433                       1.234675
#
#        region_Kuala Lumpur  region_Selangor  nearby_railways_False
# 6522             -0.978839         0.978839              -0.705352  \
# 2183              1.021619        -1.021619              -0.705352
# 12548            -0.978839         0.978839               1.417731
# 18697             1.021619        -1.021619              -0.705352
# 1395              1.021619        -1.021619              -0.705352
#
#        nearby_railways_True
# 6522               0.705352
# 2183               0.705352
# 12548             -1.417731
# 18697              0.705352
# 1395               0.705352
#
# [5 rows x 117 columns]

# %% [markdown]
# ##### Test Data Result

# %%
# libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score


#setting up
rf_tree = RandomForestRegressor(n_estimators = 500,
                                criterion = "squared_error",
                                max_features = "sqrt",
                                random_state = 123)

#fit model train
rf_tree.fit(X_train_clean, y_train.flatten())

# Predict model
y_pred_test = rf_tree.predict(X_test_clean)

# Calculate mean absolute error
mae_rf_cv_test = mean_absolute_error(y_test, y_pred_test)

# # Calculate R-squared
r2_rf_cv_test = r2_score(y_test, y_pred_test)

print(f"R2-score: {r2_rf_cv_test:.3f} and MAE score: +/-{mae_rf_cv_test:.2f} RM")

sns.scatterplot(x=y_test.flatten(), y=y_pred_test.flatten())
plt.plot([0, 5500], [0,5500], "--r")
plt.xlim(0, 5500)
plt.xlabel("Actual Monthly Rent")
plt.ylim(0,5500)
plt.ylabel("Predicted Monthly Rent")
plt.suptitle("Random Forest - Best Regression Model")
plt.show()
# Out:
# R2-score: 0.801 and MAE score: +/-187.58 RM

# %%
mae_score = [mae_rf_cv_train, mae_rf_cv_test]
r2_score = [r2_rf_cv_train, r2_rf_cv_test]
indexes = ["train", "test"]

summary_df_train_test = pd.DataFrame({
    "MAE Train": mae_score,
    "R2-Score": r2_score,
},index = indexes)

summary_df_train_test
# Out:
#         MAE Train  R2-Score
# train   87.843119  0.961990
# test   187.584422  0.801472

# %% [markdown]
# ##### Feature Importance

# %%
# calculate the feature importances
importances = rf_tree.feature_importances_

# rescale the importances back to the original scale of the features
importances = importances * X_train_clean.std()

# sort the feature importances in descending order
sorted_index = importances.argsort()[::-1]

# print the feature importances
dict_feature_importance = {}
for i in sorted_index:
    # print("{}: {}".format(X_train_clean.columns[i], importances[i]))
    dict_feature_importance.update({X_train_clean.columns[i]: importances[i]})
    
# Create a DataFrame from the dictionary
df = pd.DataFrame.from_dict(dict_feature_importance, orient='index', columns=['values'])

# Reset the index to become a column
df = df.reset_index()

# Rename the columns
df.columns = ['feature', 'importance_value']

df.sort_values(by='importance_value', ascending=False).head(10)
# Out:
#                            feature  importance_value
# 0                        size_sqft          0.203570
# 1        furnished_Fully Furnished          0.094636
# 2                  completion_year          0.067148
# 3                         bathroom          0.054256
# 4                            rooms          0.049911
# 5          property_type_Apartment          0.045015
# 6          furnished_Not Furnished          0.044541
# 7                  region_Selangor          0.034471
# 8                          parking          0.034254
# 9  property_type_Service Residence          0.029841

# %% [markdown]
# ##### Results
# Result indicates that the best model for prediction is Random Forest with hyperparameter tuning, scoring 95% on R2-score, and a shy 100 RM on MAE. This proves to be a good model since the test dataset gives a scoring of 80% on R2, and 240 RM on MAE.
#
# There are some factors that author believed to be affecting the result/ performance of the model:
#
# Dropping missing value reduces the performance! Initial model uses half of the data (4-5k rows) and gives poorer performance on R2 and MAE. Imputation and keeping the number of rows close to the original dataset (9k rows) proves to be improving the model. Especially on test dataset.
# Feature selection importance can be seen on the last table, but initially the selection was based on paper and intuition of the author (author lives and work in KL, Malaysia for 5 years). Feature such as completion_year and nearby_railways are important in improving the model.
# Last but not least is the outlier identification. The best practice for me is using jointplot to see not only the distribution of the data in 2-dimension, but also in the third dimension (the density) of the data.
# Some of the feature that were believed to be quite important even before doing the modeling is size, furnished and location. All three is available within the 10-most features affecting the modeling. As a context, location in KLCC is like Pondok Indah in South Jakarta. Location in Kiara is like BSD in South Tangerang.
#
# #### Discussions
# One of the feature that author thinks is significant but not appearing on the 10-best important feature is nearby_railways. This column is showing if a certain property has a close proximity to a railways (KTM/LRT). The issue is, half of the data is missing, hence the imputation. Author belives, the proximity to nearby railways line can be approximated using manhanttan distance of railways line to each property unit.
