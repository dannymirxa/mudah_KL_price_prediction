# %%
import sys
import polars as pl
import re
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
file_path = sys.path[0]+"/mudah-apartment-kl-selangor.csv"

# %%
df = pl.read_csv(file_path, infer_schema_length=10000)

# %%
df
# Out:
# shape: (19_991, 14)
# ┌────────────┬─────────┬────────────┬────────────┬───┬─────────┬──────────┬────────────┬───────────┐
# │ ads_id     ┆ prop_na ┆ completion ┆ monthly_re ┆ … ┆ furnish ┆ faciliti ┆ additional ┆ region    │
# │ ---        ┆ me      ┆ _year      ┆ nt         ┆   ┆ ed      ┆ es       ┆ _facilitie ┆ ---       │
# │ i64        ┆ ---     ┆ ---        ┆ ---        ┆   ┆ ---     ┆ ---      ┆ s          ┆ str       │
# │            ┆ str     ┆ f64        ┆ str        ┆   ┆ str     ┆ str      ┆ ---        ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆          ┆ str        ┆           │
# ╞════════════╪═════════╪════════════╪════════════╪═══╪═════════╪══════════╪════════════╪═══════════╡
# │ 100323185  ┆ The     ┆ 2022.0     ┆ RM 4 200   ┆ … ┆ Fully   ┆ Minimart ┆ Air-Cond,  ┆ Kuala     │
# │            ┆ Hipster ┆            ┆ per month  ┆   ┆ Furnish ┆ , Gymnas ┆ Cooking    ┆ Lumpur    │
# │            ┆ @ Taman ┆            ┆            ┆   ┆ ed      ┆ ium, Sec ┆ Allowed,   ┆           │
# │            ┆ Desa    ┆            ┆            ┆   ┆         ┆ urity,   ┆ Washi…     ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ P…       ┆            ┆           │
# │ 100203973  ┆ Segar   ┆ null       ┆ RM 2 300   ┆ … ┆ Partial ┆ Playgrou ┆ Air-Cond,  ┆ Kuala     │
# │            ┆ Courts  ┆            ┆ per month  ┆   ┆ ly Furn ┆ nd,      ┆ Cooking    ┆ Lumpur    │
# │            ┆         ┆            ┆            ┆   ┆ ished   ┆ Parking, ┆ Allowed,   ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Barbeque ┆ Near …     ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ ar…      ┆            ┆           │
# │ 100323128  ┆ Pangsap ┆ null       ┆ RM 1 000   ┆ … ┆ Fully   ┆ Minimart ┆ null       ┆ Kuala     │
# │            ┆ uri     ┆            ┆ per month  ┆   ┆ Furnish ┆ ,        ┆            ┆ Lumpur    │
# │            ┆ Teratak ┆            ┆            ┆   ┆ ed      ┆ Jogging  ┆            ┆           │
# │            ┆ Muhibba ┆            ┆            ┆   ┆         ┆ Track,   ┆            ┆           │
# │            ┆ h 2     ┆            ┆            ┆   ┆         ┆ Lift, S… ┆            ┆           │
# │ 100191767  ┆ Sentul  ┆ 2020.0     ┆ RM 1 700   ┆ … ┆ Partial ┆ Parking, ┆ Cooking    ┆ Kuala     │
# │            ┆ Point   ┆            ┆ per month  ┆   ┆ ly Furn ┆ Playgrou ┆ Allowed,   ┆ Lumpur    │
# │            ┆ Suite   ┆            ┆            ┆   ┆ ished   ┆ nd,      ┆ Near       ┆           │
# │            ┆ Apartme ┆            ┆            ┆   ┆         ┆ Swimming ┆ KTM/LRT,   ┆           │
# │            ┆ nt      ┆            ┆            ┆   ┆         ┆ Po…      ┆ W…         ┆           │
# │ …          ┆ …       ┆ …          ┆ …          ┆ … ┆ …       ┆ …        ┆ …          ┆ …         │
# │ 100371347  ┆ BSP 21  ┆ 2018.0     ┆ RM 1 300   ┆ … ┆ Partial ┆ Jogging  ┆ Air-Cond,  ┆ Selangor  │
# │            ┆         ┆            ┆ per month  ┆   ┆ ly Furn ┆ Track,   ┆ Cooking    ┆           │
# │            ┆         ┆            ┆            ┆   ┆ ished   ┆ Barbeque ┆ Allowed    ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ area,    ┆            ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Pl…      ┆            ┆           │
# │ 100493228  ┆ Ameera  ┆ null       ┆ RM 1 350   ┆ … ┆ Partial ┆ Parking, ┆ Air-Cond,  ┆ Selangor  │
# │            ┆ Residen ┆            ┆ per month  ┆   ┆ ly Furn ┆ Security ┆ Cooking    ┆           │
# │            ┆ ce      ┆            ┆            ┆   ┆ ished   ┆ , Lift,  ┆ Allowed,   ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Swimmin… ┆ Washi…     ┆           │
# │ 100235153  ┆ The Arc ┆ null       ┆ RM 1 200   ┆ … ┆ Fully   ┆ Parking, ┆ Cooking    ┆ Selangor  │
# │            ┆ @ Cyber ┆            ┆ per month  ┆   ┆ Furnish ┆ Security ┆ Allowed,   ┆           │
# │            ┆ jaya    ┆            ┆            ┆   ┆ ed      ┆ , Lift,  ┆ Washing    ┆           │
# │            ┆         ┆            ┆            ┆   ┆         ┆ Swimmin… ┆ Machine    ┆           │
# │ 100235168  ┆ Tamarin ┆ 2016.0     ┆ RM 1 000   ┆ … ┆ Partial ┆ Parking, ┆ Air-Cond,  ┆ Selangor  │
# │            ┆ d       ┆            ┆ per month  ┆   ┆ ly Furn ┆ Security ┆ Cooking    ┆           │
# │            ┆ Suites  ┆            ┆            ┆   ┆ ished   ┆ , Lift,  ┆ Allowed,   ┆           │
# │            ┆ @ Cyber ┆            ┆            ┆   ┆         ┆ Swimmin… ┆ Washi…     ┆           │
# │            ┆ jaya    ┆            ┆            ┆   ┆         ┆          ┆            ┆           │
# └────────────┴─────────┴────────────┴────────────┴───┴─────────┴──────────┴────────────┴───────────┘

# %%
df.describe()
# Out:
# shape: (7, 15)
# ┌───────────┬───────────┬─────────┬────────────┬───┬───────────┬──────────┬────────────┬───────────┐
# │ describe  ┆ ads_id    ┆ prop_na ┆ completion ┆ … ┆ furnished ┆ faciliti ┆ additional ┆ region    │
# │ ---       ┆ ---       ┆ me      ┆ _year      ┆   ┆ ---       ┆ es       ┆ _facilitie ┆ ---       │
# │ str       ┆ f64       ┆ ---     ┆ ---        ┆   ┆ str       ┆ ---      ┆ s          ┆ str       │
# │           ┆           ┆ str     ┆ f64        ┆   ┆           ┆ str      ┆ ---        ┆           │
# │           ┆           ┆         ┆            ┆   ┆           ┆          ┆ str        ┆           │
# ╞═══════════╪═══════════╪═════════╪════════════╪═══╪═══════════╪══════════╪════════════╪═══════════╡
# │ count     ┆ 19991.0   ┆ 19991   ┆ 19991.0    ┆ … ┆ 19991     ┆ 19991    ┆ 19991      ┆ 19991     │
# │ null_coun ┆ 0.0       ┆ 948     ┆ 9185.0     ┆ … ┆ 5         ┆ 2209     ┆ 5948       ┆ 0         │
# │ t         ┆           ┆         ┆            ┆   ┆           ┆          ┆            ┆           │
# │ mean      ┆ 9.9707e7  ┆ null    ┆ 2014.82232 ┆ … ┆ null      ┆ null     ┆ null       ┆ null      │
# │           ┆           ┆         ┆ 1          ┆   ┆           ┆          ┆            ┆           │
# │ std       ┆ 3.4826e6  ┆ null    ┆ 6.735355   ┆ … ┆ null      ┆ null     ┆ null       ┆ null      │
# │ min       ┆ 1.6525511 ┆ 1 Harmo ┆ 1977.0     ┆ … ┆ Fully     ┆ Barbeque ┆ ,          ┆ Kuala     │
# │           ┆ e7        ┆ nis     ┆            ┆   ┆ Furnished ┆ area     ┆ Air-Cond,  ┆ Lumpur    │
# │           ┆           ┆         ┆            ┆   ┆           ┆          ┆ Cooking    ┆           │
# │           ┆           ┆         ┆            ┆   ┆           ┆          ┆ Allowed,   ┆           │
# │           ┆           ┆         ┆            ┆   ┆           ┆          ┆ Nea…       ┆           │
# │ max       ┆ 1.0085461 ┆ wangsa  ┆ 2025.0     ┆ … ┆ Partially ┆ Tennis   ┆ Washing    ┆ Selangor  │
# │           ┆ 7e8       ┆ maju    ┆            ┆   ┆ Furnished ┆ Court,   ┆ Machine,   ┆           │
# │           ┆           ┆ section ┆            ┆   ┆           ┆ Swimming ┆ Near       ┆           │
# │           ┆           ┆ 2       ┆            ┆   ┆           ┆ Pool,    ┆ KTM/LRT,   ┆           │
# │           ┆           ┆         ┆            ┆   ┆           ┆ Squ…     ┆ I…         ┆           │
# │ median    ┆ 1.0021267 ┆ null    ┆ 2017.0     ┆ … ┆ null      ┆ null     ┆ null       ┆ null      │
# │           ┆ 8e8       ┆         ┆            ┆   ┆           ┆          ┆            ┆           │
# └───────────┴───────────┴─────────┴────────────┴───┴───────────┴──────────┴────────────┴───────────┘

# %%
df = df.filter(pl.col("region") == "Kuala Lumpur")

# %%
df.filter(df.is_duplicated())
# Out:
# shape: (0, 14)
# ┌────────┬───────────┬────────────┬────────────┬───┬───────────┬────────────┬────────────┬────────┐
# │ ads_id ┆ prop_name ┆ completion ┆ monthly_re ┆ … ┆ furnished ┆ facilities ┆ additional ┆ region │
# │ ---    ┆ ---       ┆ _year      ┆ nt         ┆   ┆ ---       ┆ ---        ┆ _facilitie ┆ ---    │
# │ i64    ┆ str       ┆ ---        ┆ ---        ┆   ┆ str       ┆ str        ┆ s          ┆ str    │
# │        ┆           ┆ f64        ┆ str        ┆   ┆           ┆            ┆ ---        ┆        │
# │        ┆           ┆            ┆            ┆   ┆           ┆            ┆ str        ┆        │
# ╞════════╪═══════════╪════════════╪════════════╪═══╪═══════════╪════════════╪════════════╪════════╡
# └────────┴───────────┴────────────┴────────────┴───┴───────────┴────────────┴────────────┴────────┘

# %%
df = df.unique()

# %%
df = df.with_columns(pl.col("monthly_rent").apply(lambda x: int(re.search(r'RM (.*?) per', x).group(1).replace(' ', ''))))
df = df.rename({"monthly_rent": "monthly_rent_rm"})

# %%
df = df.with_columns(pl.col("size").apply(lambda x: int(re.search(r'(.*?) sq', x).group(1).replace(' ', ''))))
df = df.rename({'size': 'size_sqft'})

# %%
df = df.with_columns(pl.col("location").apply(lambda x: re.sub(r"Kuala Lumpur - \s*", "", x)))

# %%
df
# Out:
# shape: (9_991, 14)
# ┌───────────┬─────────┬────────────┬────────────┬───┬─────────┬──────────┬────────────┬────────┐
# │ ads_id    ┆ prop_na ┆ completion ┆ monthly_re ┆ … ┆ furnish ┆ faciliti ┆ additional ┆ region │
# │ ---       ┆ me      ┆ _year      ┆ nt_rm      ┆   ┆ ed      ┆ es       ┆ _facilitie ┆ ---    │
# │ i64       ┆ ---     ┆ ---        ┆ ---        ┆   ┆ ---     ┆ ---      ┆ s          ┆ str    │
# │           ┆ str     ┆ f64        ┆ i64        ┆   ┆ str     ┆ str      ┆ ---        ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆          ┆ str        ┆        │
# ╞═══════════╪═════════╪════════════╪════════════╪═══╪═════════╪══════════╪════════════╪════════╡
# │ 95873723  ┆ Infinit ┆ null       ┆ 5500       ┆ … ┆ Partial ┆ Parking, ┆ Air-Cond,  ┆ Kuala  │
# │           ┆ i 3 Res ┆            ┆            ┆   ┆ ly Furn ┆ Security ┆ Cooking    ┆ Lumpur │
# │           ┆ idences ┆            ┆            ┆   ┆ ished   ┆ , Lift,  ┆ Allowed,   ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆ Swimmin… ┆ Near …     ┆        │
# │ 99507725  ┆ Idaman  ┆ null       ┆ 801        ┆ … ┆ Partial ┆ Parking, ┆ Air-Cond,  ┆ Kuala  │
# │           ┆ abadi   ┆            ┆            ┆   ┆ ly Furn ┆ Security ┆ Near       ┆ Lumpur │
# │           ┆         ┆            ┆            ┆   ┆ ished   ┆ , Lift,  ┆ KTM/LRT,   ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆ Swimmin… ┆ Cooking …  ┆        │
# │ 100061010 ┆ Amaya   ┆ 2013.0     ┆ 2300       ┆ … ┆ Fully   ┆ Multipur ┆ null       ┆ Kuala  │
# │           ┆ Maluri  ┆            ┆            ┆   ┆ Furnish ┆ pose     ┆            ┆ Lumpur │
# │           ┆         ┆            ┆            ┆   ┆ ed      ┆ hall,    ┆            ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆ Playgrou ┆            ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆ nd, S…   ┆            ┆        │
# │ 99935091  ┆ OG      ┆ 1988.0     ┆ 1300       ┆ … ┆ Partial ┆ Security ┆ Near       ┆ Kuala  │
# │           ┆ Heights ┆            ┆            ┆   ┆ ly Furn ┆ , Sauna, ┆ KTM/LRT,   ┆ Lumpur │
# │           ┆         ┆            ┆            ┆   ┆ ished   ┆ Swimming ┆ Cooking    ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆ Pool, …  ┆ Allowed    ┆        │
# │ …         ┆ …       ┆ …          ┆ …          ┆ … ┆ …       ┆ …        ┆ …          ┆ …      │
# │ 99868054  ┆ Maxim   ┆ 2017.0     ┆ 1700       ┆ … ┆ Fully   ┆ Multipur ┆ Air-Cond,  ┆ Kuala  │
# │           ┆ Citilig ┆            ┆            ┆   ┆ Furnish ┆ pose     ┆ Cooking    ┆ Lumpur │
# │           ┆ hts     ┆            ┆            ┆   ┆ ed      ┆ hall,    ┆ Allowed,   ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆ Minimart ┆ Washi…     ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆ , Jog…   ┆            ┆        │
# │ 99953379  ┆ Mawar   ┆ null       ┆ 1700       ┆ … ┆ Not Fur ┆ Minimart ┆ null       ┆ Kuala  │
# │           ┆ Sari    ┆            ┆            ┆   ┆ nished  ┆ ,        ┆            ┆ Lumpur │
# │           ┆         ┆            ┆            ┆   ┆         ┆ Parking, ┆            ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆ Security ┆            ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆ , Pla…   ┆            ┆        │
# │ 100217348 ┆ Casa    ┆ 2010.0     ┆ 1500       ┆ … ┆ Partial ┆ Parking, ┆ Washing    ┆ Kuala  │
# │           ┆ Idaman  ┆            ┆            ┆   ┆ ly Furn ┆ Security ┆ Machine,   ┆ Lumpur │
# │           ┆         ┆            ┆            ┆   ┆ ished   ┆ , Lift   ┆ Cooking    ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆          ┆ Allowed…   ┆        │
# │ 100222714 ┆ Majesti ┆ 2021.0     ┆ 1600       ┆ … ┆ Partial ┆ Parking, ┆ Air-Cond   ┆ Kuala  │
# │           ┆ c Maxim ┆            ┆            ┆   ┆ ly Furn ┆ Lift,    ┆            ┆ Lumpur │
# │           ┆         ┆            ┆            ┆   ┆ ished   ┆ Playgrou ┆            ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆ nd,      ┆            ┆        │
# │           ┆         ┆            ┆            ┆   ┆         ┆ Secur…   ┆            ┆        │
# └───────────┴─────────┴────────────┴────────────┴───┴─────────┴──────────┴────────────┴────────┘

# %%
def extract_near_ktm_lrt(text):
    pattern = re.compile(r'\bNear KTM/LRT\b')
    try:
        match = pattern.search(text)
        if match:
            return 'yes'
        return 'no'
    except TypeError:
        return text

# %%
df["additional_facilities"].apply(lambda x: extract_near_ktm_lrt(x))
# Out:
# shape: (9_991,)
# Series: 'additional_facilities' [str]
# [
# 	"yes"
# 	"yes"
# 	null
# 	"yes"
# 	null
# 	"yes"
# 	null
# 	"no"
# 	"no"
# 	"no"
# 	null
# 	null
# 	…
# 	"yes"
# 	"no"
# 	"yes"
# 	"yes"
# 	"yes"
# 	"no"
# 	"yes"
# 	"no"
# 	null
# 	"no"
# 	null
# 	"yes"
# 	"no"
# ]

# %%
df = df.select([
    pl.all(),
    pl.col("additional_facilities").apply(lambda x: extract_near_ktm_lrt(x)).alias("nearby_railways")
])

# %%
near_ktmlrt = df.filter(pl.col("nearby_railways") == "yes").select(pl.col("monthly_rent_rm")).median().item()
not_near_ktmlrt = df.filter(pl.col("nearby_railways") == "no").select(pl.col("monthly_rent_rm")).median().item()

# %%
f""" 
Median:
Nearby KTM/LRT: {near_ktmlrt:.0f}RM
Not nearby KTM/LRT: {not_near_ktmlrt:.0f}RM
"""
# Out:
# ' \nMedian:\nNearby KTM/LRT: 1650RM\nNot nearby KTM/LRT: 1600RM\n'

# %%
sns.boxplot(data=df.to_pandas(), x='monthly_rent_rm', y='nearby_railways')
plt.xlim(0,4000)
# Out:
# (0.0, 4000.0)

# %%
df.select(pl.all().is_null()).sum()
# Out:
# shape: (1, 15)
# ┌────────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬────────┬────────────┐
# │ ads_id ┆ prop_name ┆ completion ┆ monthly_re ┆ … ┆ facilities ┆ additional ┆ region ┆ nearby_rai │
# │ ---    ┆ ---       ┆ _year      ┆ nt_rm      ┆   ┆ ---        ┆ _facilitie ┆ ---    ┆ lways      │
# │ u32    ┆ u32       ┆ ---        ┆ ---        ┆   ┆ u32        ┆ s          ┆ u32    ┆ ---        │
# │        ┆           ┆ u32        ┆ u32        ┆   ┆            ┆ ---        ┆        ┆ u32        │
# │        ┆           ┆            ┆            ┆   ┆            ┆ u32        ┆        ┆            │
# ╞════════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪════════╪════════════╡
# │ 0      ┆ 508       ┆ 4373       ┆ 0          ┆ … ┆ 895        ┆ 2831       ┆ 0      ┆ 2831       │
# └────────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴────────┴────────────┘

# %%
df
# Out:
# shape: (9_991, 15)
# ┌──────────┬─────────┬────────────┬────────────┬───┬──────────┬────────────┬──────────┬────────────┐
# │ ads_id   ┆ prop_na ┆ completion ┆ monthly_re ┆ … ┆ faciliti ┆ additional ┆ region   ┆ nearby_rai │
# │ ---      ┆ me      ┆ _year      ┆ nt_rm      ┆   ┆ es       ┆ _facilitie ┆ ---      ┆ lways      │
# │ i64      ┆ ---     ┆ ---        ┆ ---        ┆   ┆ ---      ┆ s          ┆ str      ┆ ---        │
# │          ┆ str     ┆ f64        ┆ i64        ┆   ┆ str      ┆ ---        ┆          ┆ str        │
# │          ┆         ┆            ┆            ┆   ┆          ┆ str        ┆          ┆            │
# ╞══════════╪═════════╪════════════╪════════════╪═══╪══════════╪════════════╪══════════╪════════════╡
# │ 95873723 ┆ Infinit ┆ null       ┆ 5500       ┆ … ┆ Parking, ┆ Air-Cond,  ┆ Kuala    ┆ yes        │
# │          ┆ i 3 Res ┆            ┆            ┆   ┆ Security ┆ Cooking    ┆ Lumpur   ┆            │
# │          ┆ idences ┆            ┆            ┆   ┆ , Lift,  ┆ Allowed,   ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Swimmin… ┆ Near …     ┆          ┆            │
# │ 99507725 ┆ Idaman  ┆ null       ┆ 801        ┆ … ┆ Parking, ┆ Air-Cond,  ┆ Kuala    ┆ yes        │
# │          ┆ abadi   ┆            ┆            ┆   ┆ Security ┆ Near       ┆ Lumpur   ┆            │
# │          ┆         ┆            ┆            ┆   ┆ , Lift,  ┆ KTM/LRT,   ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Swimmin… ┆ Cooking …  ┆          ┆            │
# │ 10006101 ┆ Amaya   ┆ 2013.0     ┆ 2300       ┆ … ┆ Multipur ┆ null       ┆ Kuala    ┆ null       │
# │ 0        ┆ Maluri  ┆            ┆            ┆   ┆ pose     ┆            ┆ Lumpur   ┆            │
# │          ┆         ┆            ┆            ┆   ┆ hall,    ┆            ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Playgrou ┆            ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ nd, S…   ┆            ┆          ┆            │
# │ 99935091 ┆ OG      ┆ 1988.0     ┆ 1300       ┆ … ┆ Security ┆ Near       ┆ Kuala    ┆ yes        │
# │          ┆ Heights ┆            ┆            ┆   ┆ , Sauna, ┆ KTM/LRT,   ┆ Lumpur   ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Swimming ┆ Cooking    ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Pool, …  ┆ Allowed    ┆          ┆            │
# │ …        ┆ …       ┆ …          ┆ …          ┆ … ┆ …        ┆ …          ┆ …        ┆ …          │
# │ 99868054 ┆ Maxim   ┆ 2017.0     ┆ 1700       ┆ … ┆ Multipur ┆ Air-Cond,  ┆ Kuala    ┆ no         │
# │          ┆ Citilig ┆            ┆            ┆   ┆ pose     ┆ Cooking    ┆ Lumpur   ┆            │
# │          ┆ hts     ┆            ┆            ┆   ┆ hall,    ┆ Allowed,   ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Minimart ┆ Washi…     ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ , Jog…   ┆            ┆          ┆            │
# │ 99953379 ┆ Mawar   ┆ null       ┆ 1700       ┆ … ┆ Minimart ┆ null       ┆ Kuala    ┆ null       │
# │          ┆ Sari    ┆            ┆            ┆   ┆ ,        ┆            ┆ Lumpur   ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Parking, ┆            ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Security ┆            ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ , Pla…   ┆            ┆          ┆            │
# │ 10021734 ┆ Casa    ┆ 2010.0     ┆ 1500       ┆ … ┆ Parking, ┆ Washing    ┆ Kuala    ┆ yes        │
# │ 8        ┆ Idaman  ┆            ┆            ┆   ┆ Security ┆ Machine,   ┆ Lumpur   ┆            │
# │          ┆         ┆            ┆            ┆   ┆ , Lift   ┆ Cooking    ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆          ┆ Allowed…   ┆          ┆            │
# │ 10022271 ┆ Majesti ┆ 2021.0     ┆ 1600       ┆ … ┆ Parking, ┆ Air-Cond   ┆ Kuala    ┆ no         │
# │ 4        ┆ c Maxim ┆            ┆            ┆   ┆ Lift,    ┆            ┆ Lumpur   ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Playgrou ┆            ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ nd,      ┆            ┆          ┆            │
# │          ┆         ┆            ┆            ┆   ┆ Secur…   ┆            ┆          ┆            │
# └──────────┴─────────┴────────────┴────────────┴───┴──────────┴────────────┴──────────┴────────────┘

# %%
df = df.drop(['ads_id', 
    'prop_name', 
    'facilities', 
    'additional_facilities'])

# %% [raw]
# df.with_columns(pl.col("rooms").cast(pl.Int64))

# %%
df.select(pl.col("rooms")).unique()
# Out:
# shape: (10, 1)
# ┌──────────────┐
# │ rooms        │
# │ ---          │
# │ str          │
# ╞══════════════╡
# │ 2            │
# │ 6            │
# │ 3            │
# │ null         │
# │ …            │
# │ 7            │
# │ 1            │
# │ 5            │
# │ More than 10 │
# └──────────────┘

# %%
df = df.with_columns(pl.col("rooms").apply(lambda x: 10 if x == "More than 10" else x))

# %%
df = df.with_columns(pl.col("rooms").cast(pl.Float64))

# %%
df = df.with_columns(pl.col("rooms").cast(pl.Int64))

# %%
df.to_pandas()[['size_sqft', 'monthly_rent_rm']].plot(kind='scatter', x='size_sqft', y='monthly_rent_rm');
plt.ylim(100,5500)
plt.xlim(50,3000)
plt.show()

# %%
df.to_pandas()["monthly_rent_rm"].plot(kind="box", ylim = (0,20000), title='all data')
# Out:
# <Axes: title={'center': 'all data'}>

# %%
df.to_pandas()["monthly_rent_rm"].plot(kind="box", ylim = (0,5000), title='croped at 5,000 RM')
# Out:
# <Axes: title={'center': 'croped at 5,000 RM'}>

# %%
df.columns
# Out:
# ['completion_year',
#  'monthly_rent_rm',
#  'location',
#  'property_type',
#  'rooms',
#  'parking',
#  'bathroom',
#  'size_sqft',
#  'furnished',
#  'region',
#  'nearby_railways']

# %%
dfx = df.filter((pl.col("monthly_rent_rm") > 100) & (pl.col("monthly_rent_rm") < 5500))

# %%
dfx.describe()
# Out:
# shape: (7, 12)
# ┌─────────────┬────────────┬────────────┬────────────┬───┬─────────┬─────────┬────────┬────────────┐
# │ describe    ┆ completion ┆ monthly_re ┆ location   ┆ … ┆ size_sq ┆ furnish ┆ region ┆ nearby_rai │
# │ ---         ┆ _year      ┆ nt_rm      ┆ ---        ┆   ┆ ft      ┆ ed      ┆ ---    ┆ lways      │
# │ str         ┆ ---        ┆ ---        ┆ str        ┆   ┆ ---     ┆ ---     ┆ str    ┆ ---        │
# │             ┆ f64        ┆ f64        ┆            ┆   ┆ f64     ┆ str     ┆        ┆ str        │
# ╞═════════════╪════════════╪════════════╪════════════╪═══╪═════════╪═════════╪════════╪════════════╡
# │ count       ┆ 9841.0     ┆ 9841.0     ┆ 9841       ┆ … ┆ 9841.0  ┆ 9841    ┆ 9841   ┆ 9841       │
# │ null_count  ┆ 4311.0     ┆ 0.0        ┆ 0          ┆ … ┆ 0.0     ┆ 0       ┆ 0      ┆ 2778       │
# │ mean        ┆ 2014.86311 ┆ 1786.84026 ┆ null       ┆ … ┆ 11112.7 ┆ null    ┆ null   ┆ null       │
# │             ┆            ┆            ┆            ┆   ┆ 87522   ┆         ┆        ┆            │
# │ std         ┆ 7.436904   ┆ 768.813626 ┆ null       ┆ … ┆ 1.0080e ┆ null    ┆ null   ┆ null       │
# │             ┆            ┆            ┆            ┆   ┆ 6       ┆         ┆        ┆            │
# │ min         ┆ 1980.0     ┆ 110.0      ┆ Ampang     ┆ … ┆ 1.0     ┆ Fully   ┆ Kuala  ┆ no         │
# │             ┆            ┆            ┆            ┆   ┆         ┆ Furnish ┆ Lumpur ┆            │
# │             ┆            ┆            ┆            ┆   ┆         ┆ ed      ┆        ┆            │
# │ max         ┆ 2025.0     ┆ 5300.0     ┆ Wangsa     ┆ … ┆ 9.99999 ┆ Partial ┆ Kuala  ┆ yes        │
# │             ┆            ┆            ┆ Maju       ┆   ┆ 99e7    ┆ ly Furn ┆ Lumpur ┆            │
# │             ┆            ┆            ┆            ┆   ┆         ┆ ished   ┆        ┆            │
# │ median      ┆ 2017.0     ┆ 1600.0     ┆ null       ┆ … ┆ 908.0   ┆ null    ┆ null   ┆ null       │
# └─────────────┴────────────┴────────────┴────────────┴───┴─────────┴─────────┴────────┴────────────┘

# %%
dfx.to_pandas().monthly_rent_rm.plot(kind='box', x='monthly_rent_rm')
# Out:
# <Axes: >

# %%
dfx.to_pandas()["size_sqft"].plot(kind="box", ylim = (0,20000), title='all data')
# Out:
# <Axes: title={'center': 'all data'}>

# %%
dfx.to_pandas()["size_sqft"].plot(kind="box", ylim = (0,2000), title='croped at 2,000 RM')
# Out:
# <Axes: title={'center': 'croped at 2,000 RM'}>

# %%
dfx = dfx.filter((pl.col("size_sqft") > 50) & (pl.col("size_sqft") < 3000))

# %%
dfx.to_pandas()["size_sqft"].plot(kind='box')
# Out:
# <Axes: >

# %%
dfx.drop("monthly_rent_rm").to_pandas()
# Out:
#       completion_year        location      property_type  rooms  parking
# 0                 NaN     Sungai Besi        Condominium    3.0      2.0  \
# 1              2013.0          Cheras        Condominium    3.0      2.0
# 2              1988.0          Pantai        Condominium    3.0      NaN
# 3              2013.0  Old Klang Road  Service Residence    1.0      1.0
# 4              2008.0         Setapak        Condominium    4.0      1.0
# ...               ...             ...                ...    ...      ...
# 9817              NaN  Old Klang Road        Condominium    2.0      1.0
# 9818           2017.0          Sentul  Service Residence    3.0      2.0
# 9819              NaN         Keramat          Apartment    3.0      1.0
# 9820           2010.0      Jalan Ipoh        Condominium    3.0      1.0
# 9821           2021.0          Cheras  Service Residence    2.0      NaN
#
#       bathroom  size_sqft            furnished        region nearby_railways
# 0          3.0       1022  Partially Furnished  Kuala Lumpur             yes
# 1          2.0        920      Fully Furnished  Kuala Lumpur            None
# 2          2.0       1000  Partially Furnished  Kuala Lumpur             yes
# 3          1.0        350      Fully Furnished  Kuala Lumpur            None
# 4          4.0       1200  Partially Furnished  Kuala Lumpur             yes
# ...        ...        ...                  ...           ...             ...
# 9817       2.0        725      Fully Furnished  Kuala Lumpur            None
# 9818       2.0       1095      Fully Furnished  Kuala Lumpur              no
# 9819       2.0        950        Not Furnished  Kuala Lumpur            None
# 9820       2.0       1047  Partially Furnished  Kuala Lumpur             yes
# 9821       2.0        670  Partially Furnished  Kuala Lumpur              no
#
# [9822 rows x 10 columns]

# %%
dfx.select(pl.col("monthly_rent_rm")).to_numpy()
# Out:
# array([[ 801],
#        [2300],
#        [1300],
#        ...,
#        [1700],
#        [1500],
#        [1600]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(dfx.drop("monthly_rent_rm").to_pandas(),
                                                    dfx.select(pl.col("monthly_rent_rm")).to_numpy(),
                                                    test_size = 0.2,
                                                    random_state = 123)

# %%
len(X_test)/len(dfx.drop("monthly_rent_rm").to_pandas())
# Out:
# 0.20006108735491754

# %%
X_train
# Out:
#       completion_year     location      property_type  rooms  parking
# 5864           2015.0       Cheras        Condominium    3.0      1.0  \
# 2120           2021.0      Keramat          Apartment    3.0      1.0
# 9546           2009.0       Cheras        Condominium    4.0      2.0
# 8409           1998.0   Mont Kiara        Condominium    4.0      1.0
# 2764           2021.0       Sentul  Service Residence    3.0      2.0
# ...               ...          ...                ...    ...      ...
# 9785           2017.0       Sentul  Service Residence    3.0      2.0
# 7763           2008.0  City Centre        Condominium    3.0      2.0
# 5218              NaN       Cheras        Condominium    4.0      2.0
# 1346              NaN  Wangsa Maju        Condominium    4.0      2.0
# 3582           2019.0  Wangsa Maju        Condominium    4.0      3.0
#
#       bathroom  size_sqft            furnished        region nearby_railways
# 5864       2.0       1142  Partially Furnished  Kuala Lumpur             yes
# 2120       2.0        800        Not Furnished  Kuala Lumpur             yes
# 9546       3.0       1546  Partially Furnished  Kuala Lumpur            None
# 8409       2.0       1550      Fully Furnished  Kuala Lumpur             yes
# 2764       2.0        850  Partially Furnished  Kuala Lumpur              no
# ...        ...        ...                  ...           ...             ...
# 9785       2.0       1095        Not Furnished  Kuala Lumpur             yes
# 7763       2.0        960      Fully Furnished  Kuala Lumpur              no
# 5218       4.0       1933      Fully Furnished  Kuala Lumpur             yes
# 1346       2.0       1784        Not Furnished  Kuala Lumpur              no
# 3582       5.0       2336  Partially Furnished  Kuala Lumpur             yes
#
# [7857 rows x 10 columns]

# %%
print(dfx["location"].n_unique())
print(X_train.location.nunique())
print(X_test.location.nunique())
# Out:
# 60
# 60
# 53

# %%
print(dfx["property_type"].n_unique())
print(X_train.property_type.nunique())
print(X_test.property_type.nunique())
# Out:
# 9
# 8
# 9

# %%
print(set(X_train.furnished.to_list()) - set(X_test.furnished.to_list()))
print(set(X_train.location.to_list()) - set(X_test.location.to_list()))
print(set(X_train.property_type.to_list()) - set(X_test.property_type.to_list()))
print(set(X_train.nearby_railways.to_list()) - set(X_test.nearby_railways.to_list()))
# Out:
# set()
# {'Damansara', 'KL Eco City', 'Bukit Tunku', 'Salak Selatan', 'Others', 'Chan Sow Lin', 'Sungai Penchala'}
# set()
# set()

# %%
dfx["location"].value_counts().sort("counts").head(11)["location"].to_numpy()
# Out:
# array(['Sungai Penchala', 'Chan Sow Lin', 'Damansara', 'KL Eco City',
#        'Bukit Tunku', 'KL Sentral', 'Others', 'Salak Selatan',
#        'Bandar Damai Perdana', 'Jinjang', 'Serdang'], dtype=object)

# %%
dfx["property_type"].value_counts().sort("property_type")
# Out:
# shape: (9, 2)
# ┌───────────────────────────────────┬────────┐
# │ property_type                     ┆ counts │
# │ ---                               ┆ ---    │
# │ str                               ┆ u32    │
# ╞═══════════════════════════════════╪════════╡
# │ Apartment                         ┆ 2123   │
# │ Condo / Services residence / Pen… ┆ 1      │
# │ Condominium                       ┆ 4698   │
# │ Duplex                            ┆ 27     │
# │ …                                 ┆ …      │
# │ Others                            ┆ 27     │
# │ Service Residence                 ┆ 2647   │
# │ Studio                            ┆ 27     │
# │ Townhouse Condo                   ┆ 7      │
# └───────────────────────────────────┴────────┘

# %% [raw]
# dfx_new = dfx.filter(
#     (pl.col("location") != 'Jinjang') & (pl.col("location") != 'Serdang') &
#     (pl.col("location") != 'Sentral') & (pl.col("location") != 'Others') &
#     (pl.col("location") != 'Tunku') & (pl.col("location") != 'Penchala') &
#     (pl.col("location") != 'Lin') &
#     # (pl.col("property_type != 'Others') &
#     (pl.col("property_type") != 'Condo / Services residence / Penthouse / Townhouse') &
#     (pl.col("property_type") != 'Townhouse Condo'))

# %%
dfx_new = dfx.filter(
    (pl.col("location") != 'Chan Sow Lin') & (pl.col("location") != 'Sungai Penchala') &
    (pl.col("location") != 'Damansara') & (pl.col("location") != 'KL Eco City') & 
    (pl.col("location") != 'Bukit Tunku') & (pl.col("location") != 'Others') &
    (pl.col("location") != 'KL Sentral') & (pl.col("location") != 'Salak Selatan') &
    (pl.col("location") != 'Serdang') &  (pl.col("location") != 'Bandar Damai Perdana') &
    (pl.col("location") != 'Jinjang') &
    # (pl.col("property_type != 'Others') &
    (pl.col("property_type") != 'Condo / Services residence / Penthouse / Townhouse') &
    (pl.col("property_type") != 'Townhouse Condo'))

# %%
dfx_new["property_type"].value_counts()
# Out:
# shape: (7, 2)
# ┌───────────────────┬────────┐
# │ property_type     ┆ counts │
# │ ---               ┆ ---    │
# │ str               ┆ u32    │
# ╞═══════════════════╪════════╡
# │ Others            ┆ 26     │
# │ Apartment         ┆ 2112   │
# │ Service Residence ┆ 2633   │
# │ Duplex            ┆ 27     │
# │ Condominium       ┆ 4680   │
# │ Studio            ┆ 26     │
# │ Flat              ┆ 259    │
# └───────────────────┴────────┘

# %%
dfx_new
# Out:
# shape: (9_763, 11)
# ┌────────────┬────────────┬───────────┬────────────┬───┬─────────┬─────────┬──────────┬────────────┐
# │ completion ┆ monthly_re ┆ location  ┆ property_t ┆ … ┆ size_sq ┆ furnish ┆ region   ┆ nearby_rai │
# │ _year      ┆ nt_rm      ┆ ---       ┆ ype        ┆   ┆ ft      ┆ ed      ┆ ---      ┆ lways      │
# │ ---        ┆ ---        ┆ str       ┆ ---        ┆   ┆ ---     ┆ ---     ┆ str      ┆ ---        │
# │ f64        ┆ i64        ┆           ┆ str        ┆   ┆ i64     ┆ str     ┆          ┆ str        │
# ╞════════════╪════════════╪═══════════╪════════════╪═══╪═════════╪═════════╪══════════╪════════════╡
# │ null       ┆ 801        ┆ Sungai    ┆ Condominiu ┆ … ┆ 1022    ┆ Partial ┆ Kuala    ┆ yes        │
# │            ┆            ┆ Besi      ┆ m          ┆   ┆         ┆ ly Furn ┆ Lumpur   ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ished   ┆          ┆            │
# │ 2013.0     ┆ 2300       ┆ Cheras    ┆ Condominiu ┆ … ┆ 920     ┆ Fully   ┆ Kuala    ┆ null       │
# │            ┆            ┆           ┆ m          ┆   ┆         ┆ Furnish ┆ Lumpur   ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ed      ┆          ┆            │
# │ 1988.0     ┆ 1300       ┆ Pantai    ┆ Condominiu ┆ … ┆ 1000    ┆ Partial ┆ Kuala    ┆ yes        │
# │            ┆            ┆           ┆ m          ┆   ┆         ┆ ly Furn ┆ Lumpur   ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ished   ┆          ┆            │
# │ 2013.0     ┆ 1200       ┆ Old Klang ┆ Service    ┆ … ┆ 350     ┆ Fully   ┆ Kuala    ┆ null       │
# │            ┆            ┆ Road      ┆ Residence  ┆   ┆         ┆ Furnish ┆ Lumpur   ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ed      ┆          ┆            │
# │ …          ┆ …          ┆ …         ┆ …          ┆ … ┆ …       ┆ …       ┆ …        ┆ …          │
# │ 2017.0     ┆ 1700       ┆ Sentul    ┆ Service    ┆ … ┆ 1095    ┆ Fully   ┆ Kuala    ┆ no         │
# │            ┆            ┆           ┆ Residence  ┆   ┆         ┆ Furnish ┆ Lumpur   ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ed      ┆          ┆            │
# │ null       ┆ 1700       ┆ Keramat   ┆ Apartment  ┆ … ┆ 950     ┆ Not Fur ┆ Kuala    ┆ null       │
# │            ┆            ┆           ┆            ┆   ┆         ┆ nished  ┆ Lumpur   ┆            │
# │ 2010.0     ┆ 1500       ┆ Jalan     ┆ Condominiu ┆ … ┆ 1047    ┆ Partial ┆ Kuala    ┆ yes        │
# │            ┆            ┆ Ipoh      ┆ m          ┆   ┆         ┆ ly Furn ┆ Lumpur   ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ished   ┆          ┆            │
# │ 2021.0     ┆ 1600       ┆ Cheras    ┆ Service    ┆ … ┆ 670     ┆ Partial ┆ Kuala    ┆ no         │
# │            ┆            ┆           ┆ Residence  ┆   ┆         ┆ ly Furn ┆ Lumpur   ┆            │
# │            ┆            ┆           ┆            ┆   ┆         ┆ ished   ┆          ┆            │
# └────────────┴────────────┴───────────┴────────────┴───┴─────────┴─────────┴──────────┴────────────┘

# %%
X_train, X_test, y_train, y_test = train_test_split(dfx_new.drop("monthly_rent_rm").to_pandas(),
                                                    dfx_new.select(pl.col("monthly_rent_rm")).to_numpy(),
                                                    test_size = 0.2,
                                                    random_state = 123)

# %%
print(set(X_train.furnished.to_list()) - set(X_test.furnished.to_list()))
print(set(X_train.location.to_list()) - set(X_test.location.to_list()))
print(set(X_train.property_type.to_list()) - set(X_test.property_type.to_list()))
# Out:
# set()
# set()
# set()

# %%
print(dfx_new["location"].n_unique())
print(X_train.location.nunique())
print(X_test.location.nunique())
# Out:
# 49
# 49
# 49

# %%
X_train.isna().sum()
# Out:
# completion_year    3423
# location              0
# property_type         0
# rooms                 2
# parking            2042
# bathroom              0
# size_sqft             0
# furnished             0
# region                0
# nearby_railways    2198
# dtype: int64

# %%
X_train_num = X_train.select_dtypes(exclude='object')

# %%
from sklearn.impute import SimpleImputer

def numericalImputation(X_train_num, strategy = 'most_frequent'):
    #buat imputer
    imputer_num = SimpleImputer(missing_values = np.nan, strategy = strategy)
    
    #fitting
    imputer_num.fit(X_train_num)

    # transform
    imputed_data = imputer_num.transform(X_train_num)
    X_train_num_imputed = pd.DataFrame(imputed_data)

    #pastikan index dan nama kolom antara imputed dan non-imputed SAMA
    X_train_num_imputed.columns = X_train_num.columns
    X_train_num_imputed.index = X_train_num.index

    return X_train_num_imputed, imputer_num

# %%
def numericalImputationNone(X_train_num, strategy = 'most_frequent'):
    #buat imputer
    imputer_num = SimpleImputer(missing_values = None, strategy = strategy)
    
    #fitting
    imputer_num.fit(X_train_num)

    # transform
    imputed_data = imputer_num.transform(X_train_num)
    X_train_num_imputed = pd.DataFrame(imputed_data)

    #pastikan index dan nama kolom antara imputed dan non-imputed SAMA
    X_train_num_imputed.columns = X_train_num.columns
    X_train_num_imputed.index = X_train_num.index

    return X_train_num_imputed, imputer_num

# %%
X_train_num, imputer_num = numericalImputation(X_train_num, strategy='most_frequent')
X_train_num.isna().sum()
# Out:
# completion_year    0
# rooms              0
# parking            0
# bathroom           0
# size_sqft          0
# dtype: int64

# %%
X_train_cat = X_train.select_dtypes(include='object')

# %%
X_train_cat
# Out:
#               location property_type            furnished        region
# 7863            Pantai   Condominium      Fully Furnished  Kuala Lumpur  \
# 7319  Bandar Menjalara   Condominium      Fully Furnished  Kuala Lumpur
# 1878            Kepong     Apartment  Partially Furnished  Kuala Lumpur
# 5454            Kepong     Apartment  Partially Furnished  Kuala Lumpur
# 7941            Cheras   Condominium      Fully Furnished  Kuala Lumpur
# ...                ...           ...                  ...           ...
# 7382       Wangsa Maju   Condominium      Fully Furnished  Kuala Lumpur
# 7763     Jalan Kuching     Apartment      Fully Furnished  Kuala Lumpur
# 5218      Sri Petaling   Condominium      Fully Furnished  Kuala Lumpur
# 1346           Keramat   Condominium  Partially Furnished  Kuala Lumpur
# 3582              KLCC   Condominium      Fully Furnished  Kuala Lumpur
#
#      nearby_railways
# 7863             yes
# 7319              no
# 1878             yes
# 5454            None
# 7941             yes
# ...              ...
# 7382            None
# 7763             yes
# 5218              no
# 1346            None
# 3582            None
#
# [7810 rows x 5 columns]

# %%
X_train_cat.isna().sum()
# Out:
# location              0
# property_type         0
# furnished             0
# region                0
# nearby_railways    2198
# dtype: int64

# %%
X_train_cat, imputer_num = numericalImputationNone(X_train_cat, strategy='most_frequent')
X_train_cat.isna().sum()
# Out:
# location           0
# property_type      0
# furnished          0
# region             0
# nearby_railways    0
# dtype: int64

# %%
X_train_cat_ohe =  pd.get_dummies(X_train_cat)

# %%
ohe_columns = X_train_cat_ohe.columns

# %%
X_train_cat_ohe.isna().sum()
# Out:
# location_Ampang                  0
# location_Ampang Hilir            0
# location_Bandar Menjalara        0
# location_Bandar Tasik Selatan    0
# location_Bangsar                 0
#                                 ..
# furnished_Not Furnished          0
# furnished_Partially Furnished    0
# region_Kuala Lumpur              0
# nearby_railways_no               0
# nearby_railways_yes              0
# Length: 62, dtype: int64

# %%
X_train_num.isna().sum()
# Out:
# completion_year    0
# rooms              0
# parking            0
# bathroom           0
# size_sqft          0
# dtype: int64

# %%
X_train_concat = pd.concat([X_train_num, X_train_cat_ohe], axis = 1)

# %%
X_train_concat
# Out:
#       completion_year  rooms  parking  bathroom  size_sqft  location_Ampang
# 7863           2019.0    3.0      2.0       3.0     1360.0            False  \
# 7319           2021.0    5.0      2.0       3.0     1600.0            False
# 1878           2020.0    3.0      1.0       2.0      800.0            False
# 5454           2021.0    3.0      1.0       2.0     1300.0            False
# 7941           2021.0    3.0      2.0       2.0     1010.0            False
# ...               ...    ...      ...       ...        ...              ...
# 7382           2021.0    3.0      1.0       2.0      850.0            False
# 7763           2021.0    1.0      1.0       1.0      563.0            False
# 5218           2021.0    3.0      1.0       2.0      946.0            False
# 1346           2019.0    3.0      1.0       2.0     1100.0            False
# 3582           2021.0    2.0      1.0       2.0      705.0            False
#
#       location_Ampang Hilir  location_Bandar Menjalara
# 7863                  False                      False  \
# 7319                  False                       True
# 1878                  False                      False
# 5454                  False                      False
# 7941                  False                      False
# ...                     ...                        ...
# 7382                  False                      False
# 7763                  False                      False
# 5218                  False                      False
# 1346                  False                      False
# 3582                  False                      False
#
#       location_Bandar Tasik Selatan  location_Bangsar  ...
# 7863                          False             False  ...  \
# 7319                          False             False  ...
# 1878                          False             False  ...
# 5454                          False             False  ...
# 7941                          False             False  ...
# ...                             ...               ...  ...
# 7382                          False             False  ...
# 7763                          False             False  ...
# 5218                          False             False  ...
# 1346                          False             False  ...
# 3582                          False             False  ...
#
#       property_type_Flat  property_type_Others
# 7863               False                 False  \
# 7319               False                 False
# 1878               False                 False
# 5454               False                 False
# 7941               False                 False
# ...                  ...                   ...
# 7382               False                 False
# 7763               False                 False
# 5218               False                 False
# 1346               False                 False
# 3582               False                 False
#
#       property_type_Service Residence  property_type_Studio
# 7863                            False                 False  \
# 7319                            False                 False
# 1878                            False                 False
# 5454                            False                 False
# 7941                            False                 False
# ...                               ...                   ...
# 7382                            False                 False
# 7763                            False                 False
# 5218                            False                 False
# 1346                            False                 False
# 3582                            False                 False
#
#       furnished_Fully Furnished  furnished_Not Furnished
# 7863                       True                    False  \
# 7319                       True                    False
# 1878                      False                    False
# 5454                      False                    False
# 7941                       True                    False
# ...                         ...                      ...
# 7382                       True                    False
# 7763                       True                    False
# 5218                       True                    False
# 1346                      False                    False
# 3582                       True                    False
#
#       furnished_Partially Furnished  region_Kuala Lumpur  nearby_railways_no
# 7863                          False                 True               False  \
# 7319                          False                 True                True
# 1878                           True                 True               False
# 5454                           True                 True               False
# 7941                          False                 True               False
# ...                             ...                  ...                 ...
# 7382                          False                 True               False
# 7763                          False                 True               False
# 5218                          False                 True                True
# 1346                           True                 True               False
# 3582                          False                 True               False
#
#       nearby_railways_yes
# 7863                 True
# 7319                False
# 1878                 True
# 5454                 True
# 7941                 True
# ...                   ...
# 7382                 True
# 7763                 True
# 5218                False
# 1346                 True
# 3582                 True
#
# [7810 rows x 67 columns]

# %%
X_train_concat.isnull().sum()
# Out:
# completion_year                  0
# rooms                            0
# parking                          0
# bathroom                         0
# size_sqft                        0
#                                 ..
# furnished_Not Furnished          0
# furnished_Partially Furnished    0
# region_Kuala Lumpur              0
# nearby_railways_no               0
# nearby_railways_yes              0
# Length: 67, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# Buat fungsi
def standardizerData(data):
    """
    Fungsi untuk melakukan standarisasi data
    :param data: <pandas dataframe> sampel data
    :return standardized_data: <pandas dataframe> sampel data standard
    :return standardizer: method untuk standardisasi data
    """
    data_columns = data.columns  # agar nama kolom tidak hilang
    data_index = data.index  # agar index tidak hilang

    # buat (fit) standardizer
    standardizer = StandardScaler()
    standardizer.fit(data)

    # transform data
    standardized_data_raw = standardizer.transform(data)
    standardized_data = pd.DataFrame(standardized_data_raw)
    standardized_data.columns = data_columns
    standardized_data.index = data_index

    return standardized_data, standardizer

# %%
X_train_clean, standardizer = standardizerData(data = X_train_concat)

# %%
y_baseline = np.ones(len(y_train)) * y_train.mean()
y_baseline
# Out:
# array([1792.25390525, 1792.25390525, 1792.25390525, ..., 1792.25390525,
#        1792.25390525, 1792.25390525])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Train the linear regression model
lin_reg = LinearRegression().fit(X_train_clean, y_train)

# Predict using the train data
y_pred_train = y_baseline

# Calculate R-squared
r2_baseline = r2_score(y_train, y_pred_train)

#calculate MAE
mae_baseline = mean_absolute_error(y_train, y_pred_train)

print(f"R2-score: {r2_baseline:.4f} and MAE score: {mae_baseline:.4f}")
# Out:
# R2-score: 0.0000 and MAE score: 563.7968

# %%
plt.scatter(x=y_train, y=y_pred_train);

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Train the linear regression model
lin_reg = LinearRegression().fit(X_train_clean, y_train)

# Predict using the train data
# y_pred = y_baseline
y_pred_train = lin_reg.predict(X_train_clean)

# Calculate mean absolute error
mae_linreg = mean_absolute_error(y_train, y_pred_train)

# Calculate R-squared
r2_linreg = r2_score(y_train, y_pred_train)

print(f"R2-score: {r2_linreg:.4f} and MAE score: {mae_linreg:.4f}")
# Out:
# R2-score: 0.6539 and MAE score: 319.9204

# %%
y_train.flatten()
# Out:
# array([4000, 2500, 1400, ..., 1700, 1500, 1900])

# %%
y_pred_train.shape
# Out:
# (7810, 1)

# %%
sns.jointplot(x=y_train.flatten(), y=y_pred_train.flatten());

# %%
from sklearn.ensemble import GradientBoostingRegressor
# Build random forest
grad_tree = GradientBoostingRegressor(random_state = 123)

# %%
# Fit random forest
grad_tree.fit(X_train_clean, y_train)
# Out:
# /home/danialmirxa/miniconda3/envs/UM_Master/lib/python3.11/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor(random_state=123)

# %%
# Predict
y_pred_train = grad_tree.predict(X_train_clean)
# y_pred_test = grad_tree.predict(X_test_clean)

# Calculate mean absolute error
mae_gb = mean_absolute_error(y_train, y_pred_train)

# Calculate R-squared
r2_gb = r2_score(y_train, y_pred_train)

print(f"R2-score: {r2_gb:.4f} and MAE score: {mae_gb:.4f}")
# Out:
# R2-score: 0.7281 and MAE score: 281.6673

# %%
sns.jointplot(x=y_train.flatten(), y=y_pred_train.flatten());

# %%
#gridsearch

from sklearn.model_selection import GridSearchCV 


params = {'n_estimators': [100, 200, 300, 400, 500],
              'learning_rate': [0.1, 0.05, 0.01]}

# Buat gridsearch
grad_tree = GradientBoostingRegressor(random_state = 123)

grad_tree_cv = GridSearchCV(estimator = grad_tree,
                           param_grid = params,
                           cv = 5,
                           scoring = "neg_mean_absolute_error")

# %%
# Fit grid search cv
grad_tree_cv.fit(X_train_clean, y_train.flatten())
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(random_state=123),
#              param_grid={'learning_rate': [0.1, 0.05, 0.01],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              scoring='neg_mean_absolute_error')

# %%
grad_tree_cv.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 500}

# %%
# Refit the Adaboost
grad_tree = GradientBoostingRegressor(n_estimators = grad_tree_cv.best_params_["n_estimators"],
                                      random_state = 123)

grad_tree.fit(X_train_clean, y_train)
# Out:
# /home/danialmirxa/miniconda3/envs/UM_Master/lib/python3.11/site-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor(n_estimators=500, random_state=123)

# %%
# Predict
y_pred_train = grad_tree.predict(X_train_clean)

# Calculate mean absolute error
mae_gb_cv = mean_absolute_error(y_train, y_pred_train)

# Calculate R-squared
r2_gb_cv = r2_score(y_train, y_pred_train)

print(f"R2-score: {r2_gb_cv:.4f} and MAE score: {mae_gb_cv:.4f}")
# Out:
# R2-score: 0.8194 and MAE score: 228.8047

# %%
sns.jointplot(x=y_train.flatten(), y=y_pred_train.flatten())

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Build random forest
rf_tree = RandomForestRegressor(n_estimators = 100,
                                criterion = "squared_error",
                                max_features = "sqrt",
                                random_state = 123)

# %%
# Fit random forest
rf_tree.fit(X_train_clean, y_train)
# Out:
# /tmp/ipykernel_344/863500767.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_tree.fit(X_train_clean, y_train)
# RandomForestRegressor(max_features='sqrt', random_state=123)

# %%
# Predict
y_pred_train = rf_tree.predict(X_train_clean)

# Calculate mean absolute error
mae_rf = mean_absolute_error(y_train, y_pred_train)

# Calculate R-squared
r2_rf = r2_score(y_train, y_pred_train)

print(f"R2-score: {r2_rf:.4f} and MAE score: {mae_rf:.4f}")
# Out:
# R2-score: 0.9583 and MAE score: 100.9992

# %%
sns.jointplot(x=y_train.flatten(), y=y_pred_train.flatten())

# %%
params = {"n_estimators": [100, 200, 300, 500 ],
          "max_features": ["sqrt", "log2"]}

# Buat gridsearch
rf_tree = RandomForestRegressor(criterion = "squared_error",
                                random_state = 123)

rf_tree_cv = GridSearchCV(estimator = rf_tree,
                          param_grid = params,
                          cv = 5,
                          scoring = "neg_mean_absolute_error")

# %%
# Fit grid search cv
rf_tree_cv.fit(X_train_clean, y_train.flatten())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=123),
#              param_grid={'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [100, 200, 300, 500]},
#              scoring='neg_mean_absolute_error')

# %%
# Best params
rf_tree_cv.best_params_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 300}

# %%
# Refit the Random Forest
rf_tree = RandomForestRegressor(criterion = "squared_error",
                                max_features = rf_tree_cv.best_params_["max_features"],
                                n_estimators = rf_tree_cv.best_params_["n_estimators"],
                                random_state = 123)

rf_tree.fit(X_train_clean, y_train)
# Out:
# /tmp/ipykernel_344/2257456012.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_tree.fit(X_train_clean, y_train)
# RandomForestRegressor(max_features='sqrt', n_estimators=300, random_state=123)

# %%
# Predict
y_pred_train = rf_tree.predict(X_train_clean)

# Calculate mean absolute error
mae_rf_cv = mean_absolute_error(y_train, y_pred_train)

# # Calculate R-squared
r2_rf_cv = r2_score(y_train, y_pred_train)

print(f"R2-score: {r2_rf_cv:.4f} and MAE score: {mae_rf_cv:.4f}")
# Out:
# R2-score: 0.9596 and MAE score: 99.7348

# %%
sns.jointplot(x=y_train.flatten(), y=y_pred_train.flatten())

# %%
mae_score = [mae_baseline, mae_linreg, mae_gb, mae_gb_cv, mae_rf, mae_rf_cv]
r2_score = [r2_baseline, r2_linreg, r2_gb, r2_gb_cv, r2_rf, r2_rf_cv]
indexes = ["baseline", "linear regression", "gradient boosting", "gradient boosting with CV", "random forest",  "random forest with CV"]

summary_df = pd.DataFrame({
    "MAE Train": mae_score,
    "R2-Score": r2_score,
},index = indexes)

summary_df.sort_values(by='R2-Score', ascending=False)
# Out:
#                             MAE Train  R2-Score
# random forest with CV       99.734764  0.959587
# random forest              100.999190  0.958276
# gradient boosting with CV  228.804734  0.819383
# gradient boosting          281.667306  0.728074
# linear regression          319.920354  0.653922
# baseline                   563.796816  0.000000

# %%
# libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score


#setting up
rf_tree = RandomForestRegressor(n_estimators = 500,
                                criterion = "squared_error",
                                max_features = "sqrt",
                                random_state = 123)

#fit model train
rf_tree.fit(X_train_clean, y_train)

# Predict model train
y_pred_train = rf_tree.predict(X_train_clean)

# Calculate mean absolute error
mae_rf_cv_train = mean_absolute_error(y_train, y_pred_train)

# # Calculate R-squared
r2_rf_cv_train = r2_score(y_train, y_pred_train)

print(f"R2-score: {r2_rf_cv_train:.3f} and MAE score: +/-{mae_rf_cv_train:.2f} RM")

sns.scatterplot(x=y_train.flatten(), y=y_pred_train.flatten() )
plt.plot([0, 5500], [0,5500], "--r")
plt.xlim(0, 5500)
plt.xlabel("Actual Monthly Rent")
plt.ylim(0,5500)
plt.ylabel("Predicted Monthly Rent")
plt.suptitle("Random Forest - Best Regression Model")
plt.show()
# Out:
# /tmp/ipykernel_344/4192798690.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_tree.fit(X_train_clean, y_train)
# R2-score: 0.960 and MAE score: +/-99.60 RM

# %%
#checking null data
X_test.isna().sum()
# Out:
# completion_year    840
# location             0
# property_type        0
# rooms                0
# parking            534
# bathroom             0
# size_sqft            0
# furnished            0
# region               0
# nearby_railways    558
# dtype: int64

# %%
X_test_num =  X_test.select_dtypes(exclude='object')
X_test_num
# Out:
#       completion_year  rooms  parking  bathroom  size_sqft
# 7961              NaN    3.0      1.0       2.0        650
# 8435              NaN    2.0      1.0       2.0        600
# 1638              NaN    3.0      NaN       2.0        650
# 7298           2019.0    3.0      2.0       2.0       1002
# 494               NaN    3.0      NaN       2.0        935
# ...               ...    ...      ...       ...        ...
# 7989           2006.0    4.0      NaN       2.0       1016
# 5163           2005.0    3.0      1.0       2.0        950
# 4680           2013.0    2.0      NaN       1.0        737
# 8779           2006.0    1.0      1.0       1.0       2500
# 6307              NaN    2.0      1.0       2.0        555
#
# [1953 rows x 5 columns]

# %%
X_test_num.isna().sum()
# Out:
# completion_year    840
# rooms                0
# parking            534
# bathroom             0
# size_sqft            0
# dtype: int64

# %%
X_test_num, imputer_num = numericalImputation(X_test_num, strategy='most_frequent')
X_test_num.isna().sum()
# Out:
# completion_year    0
# rooms              0
# parking            0
# bathroom           0
# size_sqft          0
# dtype: int64

# %%
X_test_cat = X_test.select_dtypes(include='object')
X_test_cat
# Out:
#            location property_type            furnished        region
# 7961         Kepong     Apartment        Not Furnished  Kuala Lumpur  \
# 8435  Bangsar South     Apartment        Not Furnished  Kuala Lumpur
# 1638         Kepong     Apartment  Partially Furnished  Kuala Lumpur
# 7298        Puchong   Condominium      Fully Furnished  Kuala Lumpur
# 494          Kepong     Apartment  Partially Furnished  Kuala Lumpur
# ...             ...           ...                  ...           ...
# 7989         Sentul     Apartment  Partially Furnished  Kuala Lumpur
# 5163         Cheras   Condominium      Fully Furnished  Kuala Lumpur
# 4680     Titiwangsa   Condominium      Fully Furnished  Kuala Lumpur
# 8779           KLCC   Condominium      Fully Furnished  Kuala Lumpur
# 6307  Bangsar South     Apartment  Partially Furnished  Kuala Lumpur
#
#      nearby_railways
# 7961              no
# 8435            None
# 1638             yes
# 7298            None
# 494              yes
# ...              ...
# 7989             yes
# 5163              no
# 4680             yes
# 8779              no
# 6307             yes
#
# [1953 rows x 5 columns]

# %%
X_test_cat.isna().sum()
# Out:
# location             0
# property_type        0
# furnished            0
# region               0
# nearby_railways    558
# dtype: int64

# %%
X_test_cat, imputer_num = numericalImputation(X_test_cat, strategy='most_frequent')
X_test_cat.isna().sum()
# Out:
# location             0
# property_type        0
# furnished            0
# region               0
# nearby_railways    558
# dtype: int64

# %%
X_test_cat_ohe =  pd.get_dummies(X_test_cat)
X_test_cat_ohe.head(2)
# Out:
#       location_Ampang  location_Ampang Hilir  location_Bandar Menjalara
# 7961            False                  False                      False  \
# 8435            False                  False                      False
#
#       location_Bandar Tasik Selatan  location_Bangsar  location_Bangsar South
# 7961                          False             False                   False  \
# 8435                          False             False                    True
#
#       location_Brickfields  location_Bukit Bintang  location_Bukit Jalil
# 7961                 False                   False                 False  \
# 8435                 False                   False                 False
#
#       location_Cheras  ...  property_type_Flat  property_type_Others
# 7961            False  ...               False                 False  \
# 8435            False  ...               False                 False
#
#       property_type_Service Residence  property_type_Studio
# 7961                            False                 False  \
# 8435                            False                 False
#
#       furnished_Fully Furnished  furnished_Not Furnished
# 7961                      False                     True  \
# 8435                      False                     True
#
#       furnished_Partially Furnished  region_Kuala Lumpur  nearby_railways_no
# 7961                          False                 True                True  \
# 8435                          False                 True               False
#
#       nearby_railways_yes
# 7961                False
# 8435                False
#
# [2 rows x 62 columns]

# %%
ohe_columns = X_test_cat_ohe.columns
ohe_columns
# Out:
# Index(['location_Ampang', 'location_Ampang Hilir', 'location_Bandar Menjalara',
#        'location_Bandar Tasik Selatan', 'location_Bangsar',
#        'location_Bangsar South', 'location_Brickfields',
#        'location_Bukit Bintang', 'location_Bukit Jalil', 'location_Cheras',
#        'location_City Centre', 'location_Damansara Heights',
#        'location_Desa Pandan', 'location_Desa ParkCity',
#        'location_Desa Petaling', 'location_Gombak', 'location_Jalan Ipoh',
#        'location_Jalan Kuching', 'location_Jalan Sultan Ismail',
#        'location_KL City', 'location_KLCC', 'location_Kepong',
#        'location_Keramat', 'location_Kuchai Lama', 'location_Mid Valley City',
#        'location_Mont Kiara', 'location_OUG', 'location_Old Klang Road',
#        'location_Pandan Indah', 'location_Pandan Jaya',
#        'location_Pandan Perdana', 'location_Pantai', 'location_Puchong',
#        'location_Pudu', 'location_Segambut', 'location_Sentul',
#        'location_Seputeh', 'location_Setapak', 'location_Setiawangsa',
#        'location_Solaris Dutamas', 'location_Sri Damansara',
#        'location_Sri Hartamas', 'location_Sri Petaling',
#        'location_Sungai Besi', 'location_Taman Desa',
#        'location_Taman Melawati', 'location_Taman Tun Dr Ismail',
#        'location_Titiwangsa', 'location_Wangsa Maju',
#        'property_type_Apartment', 'property_type_Condominium',
#        'property_type_Duplex', 'property_type_Flat', 'property_type_Others',
#        'property_type_Service Residence', 'property_type_Studio',
#        'furnished_Fully Furnished', 'furnished_Not Furnished',
#        'furnished_Partially Furnished', 'region_Kuala Lumpur',
#        'nearby_railways_no', 'nearby_railways_yes'],
#       dtype='object')

# %%
X_test_concat = pd.concat([X_test_num,
                            X_test_cat_ohe],
                           axis = 1)

# %%
X_test_concat.head(2)
# Out:
#       completion_year  rooms  parking  bathroom  size_sqft  location_Ampang
# 7961           2021.0    3.0      1.0       2.0      650.0            False  \
# 8435           2021.0    2.0      1.0       2.0      600.0            False
#
#       location_Ampang Hilir  location_Bandar Menjalara
# 7961                  False                      False  \
# 8435                  False                      False
#
#       location_Bandar Tasik Selatan  location_Bangsar  ...
# 7961                          False             False  ...  \
# 8435                          False             False  ...
#
#       property_type_Flat  property_type_Others
# 7961               False                 False  \
# 8435               False                 False
#
#       property_type_Service Residence  property_type_Studio
# 7961                            False                 False  \
# 8435                            False                 False
#
#       furnished_Fully Furnished  furnished_Not Furnished
# 7961                      False                     True  \
# 8435                      False                     True
#
#       furnished_Partially Furnished  region_Kuala Lumpur  nearby_railways_no
# 7961                          False                 True                True  \
# 8435                          False                 True               False
#
#       nearby_railways_yes
# 7961                False
# 8435                False
#
# [2 rows x 67 columns]

# %%
#sanity check
X_test_concat.isnull().sum()
# Out:
# completion_year                  0
# rooms                            0
# parking                          0
# bathroom                         0
# size_sqft                        0
#                                 ..
# furnished_Not Furnished          0
# furnished_Partially Furnished    0
# region_Kuala Lumpur              0
# nearby_railways_no               0
# nearby_railways_yes              0
# Length: 67, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# Buat fungsi
def standardizerData(data):
    """
    Fungsi untuk melakukan standarisasi data
    :param data: <pandas dataframe> sampel data
    :return standardized_data: <pandas dataframe> sampel data standard
    :return standardizer: method untuk standardisasi data
    """
    data_columns = data.columns  # agar nama kolom tidak hilang
    data_index = data.index  # agar index tidak hilang

    # buat (fit) standardizer
    standardizer = StandardScaler()
    standardizer.fit(data)

    # transform data
    standardized_data_raw = standardizer.transform(data)
    standardized_data = pd.DataFrame(standardized_data_raw)
    standardized_data.columns = data_columns
    standardized_data.index = data_index

    return standardized_data, standardizer

# %%
X_test_clean, standardizer = standardizerData(data = X_test_concat)

# %%
X_test_clean.head()
# Out:
#       completion_year     rooms   parking  bathroom  size_sqft
# 7961         0.550440  0.354106 -0.558972  0.154264  -1.024374  \
# 8435         0.550440 -0.912503 -0.558972  0.154264  -1.204687
# 1638         0.550440  0.354106 -0.558972  0.154264  -1.024374
# 7298         0.238346  0.354106  1.646427  0.154264   0.245028
# 494          0.550440  0.354106 -0.558972  0.154264   0.003409
#
#       location_Ampang  location_Ampang Hilir  location_Bandar Menjalara
# 7961        -0.184066              -0.099117                  -0.064134  \
# 8435        -0.184066              -0.099117                  -0.064134
# 1638        -0.184066              -0.099117                  -0.064134
# 7298        -0.184066              -0.099117                  -0.064134
# 494         -0.184066              -0.099117                  -0.064134
#
#       location_Bandar Tasik Selatan  location_Bangsar  ...
# 7961                      -0.032017          -0.07174  ...  \
# 8435                      -0.032017          -0.07174  ...
# 1638                      -0.032017          -0.07174  ...
# 7298                      -0.032017          -0.07174  ...
# 494                       -0.032017          -0.07174  ...
#
#       property_type_Flat  property_type_Others
# 7961           -0.174948             -0.045303  \
# 8435           -0.174948             -0.045303
# 1638           -0.174948             -0.045303
# 7298           -0.174948             -0.045303
# 494            -0.174948             -0.045303
#
#       property_type_Service Residence  property_type_Studio
# 7961                        -0.598445             -0.064134  \
# 8435                        -0.598445             -0.064134
# 1638                        -0.598445             -0.064134
# 7298                        -0.598445             -0.064134
# 494                         -0.598445             -0.064134
#
#       furnished_Fully Furnished  furnished_Not Furnished
# 7961                  -0.904674                 2.404423  \
# 8435                  -0.904674                 2.404423
# 1638                  -0.904674                -0.415900
# 7298                   1.105370                -0.415900
# 494                   -0.904674                -0.415900
#
#       furnished_Partially Furnished  region_Kuala Lumpur  nearby_railways_no
# 7961                      -0.820684                  0.0            1.605280  \
# 8435                      -0.820684                  0.0           -0.622944
# 1638                       1.218496                  0.0           -0.622944
# 7298                      -0.820684                  0.0           -0.622944
# 494                        1.218496                  0.0           -0.622944
#
#       nearby_railways_yes
# 7961            -0.876939
# 8435            -0.876939
# 1638             1.140330
# 7298            -0.876939
# 494              1.140330
#
# [5 rows x 67 columns]

# %%
# libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score


#setting up
rf_tree = RandomForestRegressor(n_estimators = 500,
                                criterion = "squared_error",
                                max_features = "sqrt",
                                random_state = 123)

#fit model train
rf_tree.fit(X_train_clean, y_train)

# Predict model
y_pred_test = rf_tree.predict(X_test_clean)

# Calculate mean absolute error
mae_rf_cv_test = mean_absolute_error(y_test, y_pred_test)

# # Calculate R-squared
r2_rf_cv_test = r2_score(y_test, y_pred_test)

print(f"R2-score: {r2_rf_cv_test:.3f} and MAE score: +/-{mae_rf_cv_test:.2f} RM")

sns.scatterplot(x=y_test.flatten(), y=y_pred_test.flatten())
plt.plot([0, 5500], [0,5500], "--r")
plt.xlim(0, 5500)
plt.xlabel("Actual Monthly Rent")
plt.ylim(0,5500)
plt.ylabel("Predicted Monthly Rent")
plt.suptitle("Random Forest - Best Regression Model")
plt.show()
# Out:
# /tmp/ipykernel_344/674961200.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_tree.fit(X_train_clean, y_train)
# R2-score: 0.784 and MAE score: +/-225.48 RM

# %%
mae_score = [mae_rf_cv_train, mae_rf_cv_test]
r2_score = [r2_rf_cv_train, r2_rf_cv_test]
indexes = ["train", "test"]

summary_df_train_test = pd.DataFrame({
    "MAE Train": mae_score,
    "R2-Score": r2_score,
},index = indexes)

summary_df_train_test
# Out:
#         MAE Train  R2-Score
# train   99.601877  0.959628
# test   225.483815  0.783881

# %%
# calculate the feature importances
importances = rf_tree.feature_importances_

# rescale the importances back to the original scale of the features
importances = importances * X_train_clean.std()

# sort the feature importances in descending order
sorted_index = importances.argsort()[::-1]

# print the feature importances
dict_feature_importance = {}
for i in sorted_index:
    # print("{}: {}".format(X_train_clean.columns[i], importances[i]))
    dict_feature_importance.update({X_train_clean.columns[i]: importances[i]})
    
# Create a DataFrame from the dictionary
df = pd.DataFrame.from_dict(dict_feature_importance, orient='index', columns=['values'])

# Reset the index to become a column
df = df.reset_index()

# Rename the columns
df.columns = ['feature', 'importance_value']

df.sort_values(by='importance_value', ascending=False).head(10)
# Out:
#                      feature  importance_value
# 0                  size_sqft          0.222484
# 1  furnished_Fully Furnished          0.116090
# 2            completion_year          0.073512
# 3                   bathroom          0.060770
# 4                      rooms          0.046789
# 5        location_Mont Kiara          0.045317
# 6                    parking          0.043784
# 7    property_type_Apartment          0.037627
# 8              location_KLCC          0.037180
# 9    furnished_Not Furnished          0.036066
